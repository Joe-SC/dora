# %% [markdown]
# # Model Development

# %%
import pandas as pd
import numpy as np
import json
import seaborn as sns
import tqdm
import re
import pandas_profiling
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn-paper')

from ml_utils.preprocessing import target_melt
from ml_utils.tools import format_timedelta
import datetime

# %%
# from ml_utils.preprocessing import CategoricalEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from category_encoders import MEstimateEncoder, JamesSteinEncoder
from sklearn.preprocessing import MinMaxScaler
from imblearn.combine import SMOTEENN
from imblearn.over_sampling import ADASYN
from xgboost.sklearn import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score, \
                            roc_curve, \
                            auc, \
                            classification_report, \
                            confusion_matrix, \
                            accuracy_score, \
                            precision_score, \
                            recall_score, \
                            f1_score

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";var r=n(11),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var i=Object.getOwnPropertySymbols,o=Object.prototype.hasOwnProperty,a=Object.prototype.propertyIsEnumerable;t.exports=function(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;if("0123456789"!==Object.getOwnPropertyNames(e).map(function(t){return e[t]}).join(""))return!1;var r={};return"abcdefghijklmnopqrst".split("").forEach(function(t){r[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},r)).join("")}catch(t){return!1}}()?Object.assign:function(t,e){for(var n,u,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)o.call(n,l)&&(c[l]=n[l]);if(i){u=i(n);for(var f=0;f<u.length;f++)a.call(n,u[f])&&(c[u[f]]=n[u[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode&&f("33"),t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent||f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(1),p=n(21),h=n(161),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o,a=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return a;do{a.push(o=new Date(+n)),e(n,i),t(n)}while(o<n&&n<r);return a},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)if(r<0)for(;++r<=0;)for(;e(t,-1),!n(t););else for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t==0}:function(e){return u.count(0,e)%t==0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(19);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(193);n.d(e,"cross",function(){return a.a});var u=n(194);n.d(e,"descending",function(){return u.a});var c=n(103);n.d(e,"deviation",function(){return c.a});var s=n(104);n.d(e,"extent",function(){return s.a});var l=n(195);n.d(e,"histogram",function(){return l.a});var f= ...

# %%
import optunity
import optunity.metrics

# %%
vcdb = pd.read_excel('data/vcdb_decoded.xlsx')

# %%
pd.__version__
# Out:
# '1.0.1'

# %%
with open('data/vcdb-enum.json') as f:
    enums = json.load(f)
    
with open('data/vcdb-merged.json') as f:
    schema = json.load(f)

# %%
keynames = []
with open('data/vcdb-keynames-real.txt') as f:
    for line in f:
        keynames.append(line.replace('\n', ''))

# %% [markdown]
# # Creating a configuration file / data dictionary

# %%
config = {
    'base_data': {},
    'targets': {}
}

# %% [markdown]
# # One-hot encoded features

# %%
ohe_cols = [col for col in vcdb if vcdb[col].isin([True, False]).all()]
print('%s hot encoded features'%len(ohe_cols))
      
assert vcdb[ohe_cols].notnull().all().all()
assert len(ohe_cols) == len(vcdb.select_dtypes('bool').columns)
# Out:
# 476 hot encoded features

# %%
config['base_data']['one-hot encoded'] = ohe_cols

# %% [markdown]
# # Null Columns

# %%
null_cols = vcdb.columns[vcdb.isnull().all()]
null_cols = [col for col in null_cols if col not in ohe_cols]
print('%s completely null features'%len(null_cols))
config['base_data']['all null'] = null_cols
# Out:
# 91 completely null features

# %% [markdown]
# Some of these are fine because they are one_hot encoded columns

# %%
some_nulls = [col for col in vcdb.columns[vcdb.isnull().any()] if col not in null_cols]
print('%s features with some nulls'%len(some_nulls))
config['base_data']['some null'] = some_nulls
# Out:
# 115 features with some nulls

# %% [markdown]
# ## Null categorical features with an Unknown category
# We replace columns with "Unknown" as a value with pandas nulls, this way we can figure out a good imputation strategy for these rather than treat "unknown" as a category, since it is not useful to us.

# %%
ukn_cols = [col for col in some_nulls if (vcdb[col].astype(str).str.lower()=='unknown').any()]
for col in ukn_cols:
    vcdb.loc[vcdb[col].astype(str).str.lower()=='unknown', col] = None

assert not vcdb[ukn_cols].apply(lambda col: (col.astype(str).str.lower()=='unknown').any()).any()
config['base_data']['explicitly unknown'] = ukn_cols

# %% [markdown]
# # Data Types

# %% [markdown]
# ### Floats

# %%
vcdb.select_dtypes('float64').notnull().sum().sort_values(ascending=False)
# Out:
# attribute.confidentiality.data_total                 4394
# attribute.confidentiality.data.amount.Medical        1711
# attribute.confidentiality.data.amount.Personal       1192
# victim.locations_affected                            1185
# victim.revenue.amount                                 505
#                                                      ...
# asset.assets.amount.U - Telephone                       0
# asset.assets.amount.U - Unknown                         0
# asset.assets.amount.U - VoIP phone                      0
# attribute.confidentiality.data.amount.Source code       0
# asset.assets.amount.E - Other                           0
# Length: 149, dtype: int64

# %%
vcdb.dtypes.value_counts()
# Out:
# bool       476
# float64    149
# object      66
# int64        1
# dtype: int64

# %%
float_cols = [col for col in vcdb.select_dtypes('float64') if not vcdb[col].isnull().all()]
len(float_cols)
config['base_data']['floats'] = float_cols

# %% [markdown]
# ## Free Text

# %%
text_cols = [col for col in vcdb if 'notes' in col.lower() or 'summary' in col.lower()]
text_cols += ['reference']
text_cols
# Out:
# ['action.environmental.notes',
#  'action.error.notes',
#  'action.hacking.notes',
#  'action.malware.notes',
#  'action.misuse.notes',
#  'action.physical.notes',
#  'action.social.notes',
#  'action.unknown.notes',
#  'asset.notes',
#  'attribute.availability.notes',
#  'attribute.confidentiality.notes',
#  'attribute.integrity.notes',
#  'discovery_notes',
#  'impact.notes',
#  'notes',
#  'plus.analyst_notes',
#  'plus.event_chain.summary',
#  'plus.pci.notes',
#  'summary',
#  'victim.notes',
#  'victim.secondary.notes',
#  'reference']

# %%
vcdb[text_cols].notnull().sum()
# Out:
# action.environmental.notes            1
# action.error.notes                  299
# action.hacking.notes                192
# action.malware.notes                102
# action.misuse.notes                 118
# action.physical.notes                30
# action.social.notes                  60
# action.unknown.notes                  5
# asset.notes                         173
# attribute.availability.notes        114
# attribute.confidentiality.notes     727
# attribute.integrity.notes           234
# discovery_notes                     415
# impact.notes                        133
# notes                               423
# plus.analyst_notes                  167
# plus.event_chain.summary              0
# plus.pci.notes                        0
# summary                            7329
# victim.notes                         62
# victim.secondary.notes               74
# reference                          7379
# dtype: int64

# %% [markdown]
# ## Text cleaning

# %%
cat_and_text_cols = vcdb.select_dtypes('O').columns
for col in cat_and_text_cols:
    vcdb[col] = (
        vcdb[col]
            .fillna('placeholder_nan')
            .astype(str)
            .str.lower()
            .replace('placeholder_nan', np.nan)
    )

# %% [markdown]
# ## Categoricals

# %%
{col: vcdb[col].unique() for col in vcdb if 'cve' in col}
# Out:
# {'action.hacking.cve': array([nan, 'cve-2008-4250', 'heartbleed', 'cve-2012-0507',
#         'unknown vuln', 'cve-2016-6483', 'cve unknown', 'cve-2012-5385',
#         'cve-2014-0160', 'cve-2017-5638', 'cve-2012-4969', 'cve-2013-0632',
#         'cve-2013-1347,cve-2013-2423,cve-2013-1493', 'cve-2017-0144',
#         'wordpress'], dtype=object),
#  'action.malware.cve': array([nan, 'cve-2010-0249',
#         'cve-2009-3129, cve-2010-3333, cve-2012-0158, cve-2011-3544',
#         'cve-2013-0640,cve-2013-0641', 'cve-2012-4681;cve-2013-2423',
#         'cve-2013-3893', 'cve 2012-4792',
#         'cve-2013-1347, cve-2013-2423, cve-2013-1493', 'cve-2012-4681'],
#        dtype=object)}

# %%
feature_counts = {}
for col in vcdb.select_dtypes('O'):
    if 'notes' not in col.lower() and col not in ohe_cols:
        feature_counts[col]= vcdb[col].nunique()
feature_counts
# Out:
# {'action.hacking.cve': 14,
#  'action.malware.cve': 8,
#  'action.malware.name': 21,
#  'campaign_id': 10,
#  'control_failure': 1,
#  'incident_id': 7829,
#  'plus.analyst': 69,
#  'plus.asset.total': 3,
#  'plus.attribute.confidentiality.credit_monitoring': 5,
#  'plus.attribute.confidentiality.data_abuse': 3,
#  'plus.attribute.confidentiality.data_misuse': 4,
#  'plus.attribute.confidentiality.partner_data': 2,
#  'plus.f500': 6,
#  'plus.github': 4344,
#  'plus.master_id': 7832,
#  'plus.sub_source': 4,
#  'reference': 5925,
#  'schema_version': 2,
#  'source_id': 1,
#  'summary': 6936,
#  'victim.industry': 670,
#  'victim.region': 38,
#  'victim.secondary.victim_id': 234,
#  'victim.state': 97,
#  'victim.victim_id': 5616,
#  'victim.industry3': 115,
#  'victim.industry.name': 21,
#  'pattern': 10,
#  'security_incident': 3,
#  'impact.overall_rating': 4,
#  'impact.iso_currency_code': 10,
#  'confidence': 4,
#  'victim.employee_count': 11,
#  'victim.country': 134,
#  'victim.revenue.iso_currency_code': 2,
#  'victim.orgsize': 2,
#  'attribute.availability.duration.unit': 7,
#  'attribute.confidentiality.data_disclosure': 3,
#  'targeted': 2,
#  'cost_corrective_action': 2,
#  'asset.cloud': 5,
#  'asset.accessibility': 1,
#  'asset.country': 11,
#  'plus.analysis_status': 5,
#  'plus.attack_difficulty_initial': 4,
#  'plus.attack_difficulty_legacy': 5,
#  'plus.attack_difficulty_subsequent': 4,
#  'plus.unknown_unknowns': 2}

# %%
vcdb[feature_counts.keys()]
# Out:
#      action.hacking.cve action.malware.cve action.malware.name campaign_id  \
# 0                   NaN                NaN                 NaN         NaN
# 1                   NaN                NaN                 NaN         NaN
# 2                   NaN                NaN                 NaN         NaN
# 3                   NaN                NaN                 NaN         NaN
# 4                   NaN                NaN                 NaN         NaN
# ...                 ...                ...                 ...         ...
# 7828                NaN                NaN                 NaN         NaN
# 7829                NaN                NaN                 NaN         NaN
# 7830                NaN                NaN                 NaN         NaN
# 7831                NaN                NaN                 NaN         NaN
# 7832                NaN                NaN                 NaN         NaN
#
#      control_failure                           incident_id   plus.analyst  \
# 0                NaN  0001aa7f-c601-424a-b2b8-be6c9f5164e7         swidup
# 1                NaN  0008dadb-e83d-4278-a19a-cee01610cf43         swidup
# 2                NaN  000d403e-2dc9-4ea7-9294-bd3938d1c3c7         swidup
# 3                NaN  0012cc25-9167-40d8-8fe3-3d0dfd8fb6bb         swidup
# 4                NaN  00163384-b4d7-46d5-9e6f-543dfb00f598         swidup
# ...              ...                                   ...            ...
# 7828             NaN  b533254c-4713-4fe7-a9f8-412abb4ec664  robert-topper
# 7829             NaN  ffd31fe4-976b-48ca-a111-ef84ebab9b0f         swidup
# 7830             NaN  ffda2281-8053-4315-b613-330eb09a4bee         swidup
# 7831             NaN  ffdc6655-e421-4bec-835f-1bdfec4f6c70         swidup
# 7832             NaN  ffe36843-d23a-484f-a9b8-1338c9be49cd         swidup
#
#      plus.asset.total plus.attribute.confidentiality.credit_monitoring  \
# 0                 NaN                                              NaN
# 1                 NaN                                                u
# 2                 NaN                                                y
# 3                  no                                                u
# 4                 NaN                                              NaN
# ...               ...                                              ...
# 7828              NaN                                                u
# 7829              NaN                                                y
# 7830               no                                                u
# 7831               no                                                u
# 7832              NaN                                              NaN
#
#      plus.attribute.confidentiality.data_abuse  ... targeted  \
# 0                                          NaN  ...      NaN
# 1                                          NaN  ...      NaN
# 2                                          NaN  ...      NaN
# 3                                            y  ...      NaN
# 4                                          NaN  ...      NaN
# ...                                        ...  ...      ...
# 7828                                       NaN  ...      NaN
# 7829                                       NaN  ...      NaN
# 7830                                         y  ...      NaN
# 7831                                         u  ...      NaN
# 7832                                       NaN  ...      NaN
#
#      cost_corrective_action asset.cloud asset.accessibility asset.country  \
# 0                       NaN         NaN                 NaN           NaN
# 1                       NaN         NaN                 NaN           NaN
# 2                       NaN         NaN                 NaN           NaN
# 3                       NaN         NaN                 NaN           NaN
# 4                       NaN         NaN                 NaN           NaN
# ...                     ...         ...                 ...           ...
# 7828                    NaN         NaN                 NaN           NaN
# 7829                    NaN         NaN                 NaN           NaN
# 7830                    NaN         NaN                 NaN           NaN
# 7831                    NaN         NaN                 NaN           NaN
# 7832                    NaN         NaN                 NaN           NaN
#
#      plus.analysis_status plus.attack_difficulty_initial  \
# 0              first pass                            NaN
# 1              first pass                            NaN
# 2              first pass                            NaN
# 3              first pass                            NaN
# 4              first pass                            NaN
# ...                   ...                            ...
# 7828            finalized                            NaN
# 7829           first pass                            NaN
# 7830           first pass                            NaN
# 7831           first pass                            NaN
# 7832           first pass                            NaN
#
#      plus.attack_difficulty_legacy plus.attack_difficulty_subsequent  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
# ...                            ...                               ...
# 7828                           NaN                               NaN
# 7829                           NaN                               NaN
# 7830                           NaN                               NaN
# 7831                           NaN                               NaN
# 7832                           NaN                               NaN
#
#      plus.unknown_unknowns
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 7828                   NaN
# 7829                   NaN
# 7830                   NaN
# 7831                   NaN
# 7832                   NaN
#
# [7833 rows x 48 columns]

# %%
def id_generator(dict_var, key):
    """
    Based.
    https://stackoverflow.com/questions/21028979/recursive-iteration-through-nested-json-for-specific-key-in-python
    """
    for k, v in dict_var.items():
        if k == key:
            yield v
        elif isinstance(v, dict):
            for id_val in id_generator(v, key):
                yield id_val

# %%
enums = set()
for enum in id_generator(schema,'enum'):
    enums.add(tuple(enum))

len(enums)
# Out:
# 66

# %%
pd.Categorical(vcdb['security_incident']).categories
# Out:
# Index(['confirmed', 'near miss', 'suspected'], dtype='object')

# %% [markdown]
# # Target Variable Analysis

# %% [markdown]
# We start by having at some Incident Description Enumerations to see what is feasible.
#
# #### SECURITY_INCIDENT
# - Confirmed: Yes - Confirmed
# - Suspected: Suspected
# - False positive: False positive (response triggered, but no incident)
# - Near miss: Near miss (actions did not compromise asset)

# %%
config['targets']['All'] = []

# %%
schema['properties']['security_incident']
# Out:
# {'type': 'string',
#  'description': 'Confirmed incident?',
#  'enum': ['Confirmed', 'Suspected', 'Near miss', 'False positive']}

# %%
vcdb['security_incident'].value_counts(dropna=False)
# Out:
# confirmed    7759
# suspected      67
# near miss       6
# NaN             1
# Name: security_incident, dtype: int64

# %%
config['targets']['All'].append('security_incident')

# %%
impact_cols = [col for col in vcdb if col.startswith('impact')]

# %%
vcdb[[col for col in vcdb if col.startswith('impact')]].notnull().sum()
# Out:
# impact.loss.amount             0
# impact.notes                 133
# impact.overall_amount         80
# impact.overall_max_amount      1
# impact.overall_min_amount      2
# impact.overall_rating         27
# impact.iso_currency_code     197
# dtype: int64

# %%
vcdb['impact.overall_rating'].value_counts(dropna=False)
# Out:
# NaN              7806
# distracting        13
# damaging            8
# painful             5
# insignificant       1
# Name: impact.overall_rating, dtype: int64

# %%
config['targets']['All'] += [col for col in vcdb if col.startswith('impact')]

# %% [markdown]
# # Predicting C-I-A outcomes

# %%
cia_cols = [col for col in vcdb if col.startswith('attribute.')]
config['targets']['All CIA'] = cia_cols

# %% [markdown]
# Data Disclosure looks promising as a decision outcome: while there is a class imbalance it is not as extreme as that of security_incidents

# %%
vcdb['attribute.confidentiality.data_disclosure'].value_counts()
# Out:
# yes            5076
# potentially    1884
# no               76
# Name: attribute.confidentiality.data_disclosure, dtype: int64

# %%
config['targets']['data_disclosure'] = 'attribute.confidentiality.data_disclosure'

# %% [markdown]
# Availability Duration does not seem promising as a decision outcome

# %%
config['targets']['All'] += [col for col in vcdb if col.startswith('attribute')]

# %%
vcdb['attribute.Confidentiality'].value_counts()
# Out:
# True     7249
# False     584
# Name: attribute.Confidentiality, dtype: int64

# %%
[col for col in vcdb if col.startswith('attribute.confidentiality') and 'variety' in col]
# Out:
# ['attribute.confidentiality.data.variety.Bank',
#  'attribute.confidentiality.data.variety.Classified',
#  'attribute.confidentiality.data.variety.Copyrighted',
#  'attribute.confidentiality.data.variety.Credentials',
#  'attribute.confidentiality.data.variety.Digital certificate',
#  'attribute.confidentiality.data.variety.Internal',
#  'attribute.confidentiality.data.variety.Medical',
#  'attribute.confidentiality.data.variety.Other',
#  'attribute.confidentiality.data.variety.Payment',
#  'attribute.confidentiality.data.variety.Personal',
#  'attribute.confidentiality.data.variety.Secrets',
#  'attribute.confidentiality.data.variety.Source code',
#  'attribute.confidentiality.data.variety.System',
#  'attribute.confidentiality.data.variety.Unknown',
#  'attribute.confidentiality.data.variety.Virtual currency']

# %%
vcdb['attribute.Integrity'].value_counts()
# Out:
# False    5998
# True     1835
# Name: attribute.Integrity, dtype: int64

# %%
[col for col in vcdb if col.startswith('attribute.integrity')]
# Out:
# ['attribute.integrity.notes',
#  'attribute.integrity.variety.Alter behavior',
#  'attribute.integrity.variety.Created account',
#  'attribute.integrity.variety.Defacement',
#  'attribute.integrity.variety.Fraudulent transaction',
#  'attribute.integrity.variety.Hardware tampering',
#  'attribute.integrity.variety.Log tampering',
#  'attribute.integrity.variety.Misrepresentation',
#  'attribute.integrity.variety.Modify configuration',
#  'attribute.integrity.variety.Modify data',
#  'attribute.integrity.variety.Modify privileges',
#  'attribute.integrity.variety.Other',
#  'attribute.integrity.variety.Repurpose',
#  'attribute.integrity.variety.Software installation',
#  'attribute.integrity.variety.Unknown']

# %%
vcdb['attribute.Availability'].value_counts()
# Out:
# False    5486
# True     2347
# Name: attribute.Availability, dtype: int64

# %%
[col for col in vcdb if col.startswith('attribute.availability')]
# Out:
# ['attribute.availability.duration.value',
#  'attribute.availability.notes',
#  'attribute.availability.variety.Acceleration',
#  'attribute.availability.variety.Degradation',
#  'attribute.availability.variety.Destruction',
#  'attribute.availability.variety.Interruption',
#  'attribute.availability.variety.Loss',
#  'attribute.availability.variety.Obscuration',
#  'attribute.availability.variety.Other',
#  'attribute.availability.variety.Unknown',
#  'attribute.availability.duration.unit']

# %%
vcdb['attribute.availability.duration.value'].notnull().sum()
# Out:
# 106

# %%
vcdb['control_failure'].value_counts(dropna=False)
# Out:
# NaN                             7832
# single factor authentication       1
# Name: control_failure, dtype: int64

# %% [markdown]
# ## Predicting Pattern Outcomes

# %%
vcdb['pattern'].value_counts()
# Out:
# miscellaneous errors      1812
# privilege misuse          1597
# lost and stolen assets    1460
# everything else           1026
# web applications           896
# payment card skimmers      278
# crimeware                  267
# cyber-espionage            247
# denial of service          162
# point of sale               88
# Name: pattern, dtype: int64

# %%
config['targets']['All'].append('pattern')

# %%
pattern_cols = [col for col in vcdb if col.startswith('pattern.')]
pattern_cols
# Out:
# ['pattern.Point of Sale',
#  'pattern.Web Applications',
#  'pattern.Privilege Misuse',
#  'pattern.Lost and Stolen Assets',
#  'pattern.Miscellaneous Errors',
#  'pattern.Crimeware',
#  'pattern.Payment Card Skimmers',
#  'pattern.Denial of Service',
#  'pattern.Cyber-Espionage',
#  'pattern.Everything Else']

# %%
vcdb[pattern_cols].sum(axis=1).value_counts()
# Out:
# 1    7732
# 2     101
# dtype: int64

# %%
target_melt(vcdb, pattern_cols)['target'].value_counts(dropna=False)
# Out:
# Miscellaneous Errors      1812
# Privilege Misuse          1604
# Lost and Stolen Assets    1505
# Everything Else           1026
# Web Applications           900
# Payment Card Skimmers      290
# Cyber-Espionage            280
# Crimeware                  267
# Denial of Service          162
# Point of Sale               88
# Name: target, dtype: int64

# %%
config['targets']['All'] += pattern_cols

# %% [markdown]
# ## Asset Cols

# %%
asset_cols = [col for col in vcdb if col.startswith('asset.')]
len(asset_cols)
# Out:
# 220

# %% [markdown]
# ## Actions as Outcomes or Features

# %%
action_cols = [col for col in vcdb if col.startswith('action.')]

# %%
vcdb['action.Social'].value_counts()
# Out:
# False    7318
# True      515
# Name: action.Social, dtype: int64

# %% [markdown]
# #### Action Results are very null

# %%
vcdb[[col for col in vcdb if col.startswith('action.') and 'result' in col]].sum(axis=1).value_counts()
# Out:
# 0    7555
# 1     199
# 2      77
# 3       2
# dtype: int64

# %% [markdown]
# #### Action Variety Cols
# Potentially useful for making predictions
#
# Should we melt these to create separate records

# %%
action_variety_cols = [col for col in vcdb if col.startswith('action.') and 'variety' in col]
len(action_variety_cols)
# Out:
# 155

# %%
vcdb[action_variety_cols].sum(axis=1).value_counts()
# Out:
# 1     6273
# 2      935
# 0      210
# 3      172
# 13      88
# 9       74
# 4       42
# 5       26
# 6        9
# 7        3
# 8        1
# dtype: int64

# %%
target_melt(vcdb, action_variety_cols, split=False)['target'].value_counts()
# Out:
# action.hacking.variety.Unknown                1334
# action.physical.variety.Theft                 1128
# action.misuse.variety.Privilege abuse         1110
# action.error.variety.Misdelivery               910
# action.error.variety.Loss                      391
#                                               ...
# action.hacking.variety.Session prediction        1
# action.hacking.variety.Reverse engineering       1
# action.error.variety.Misinformation              1
# action.environmental.variety.Humidity            1
# action.social.variety.Spam                       1
# Name: target, Length: 109, dtype: int64

# %% [markdown]
# #### Action Vector Cols
# Potentially useful for making predictions
#
# Should we melt these to create separate records

# %%
action_vector_cols = [col for col in vcdb if col.startswith('action.') and 'vector' in col]
len(action_vector_cols)
# Out:
# 66

# %%
vcdb[action_vector_cols].sum(axis=1).value_counts()
# Out:
# 1    6797
# 2     535
# 3     251
# 0     217
# 4      29
# 5       3
# 6       1
# dtype: int64

# %% [markdown]
# #### Action Result Cols
# Potentially useful for making predictions
#
# Should we melt these to create separate records

# %%
action_result_cols = [col for col in vcdb if col.startswith('action.') and 'result' in col]

# %%
target_melt(vcdb, action_result_cols, split=False)['target'].shape
# Out:
# (359,)

# %%
target_melt(vcdb, action_result_cols, split=False)['target'].value_counts()
# Out:
# action.misuse.result.Exfiltrate      82
# action.hacking.result.Exfiltrate     63
# action.physical.result.Exfiltrate    55
# action.hacking.result.Infiltrate     49
# action.malware.result.Exfiltrate     30
# action.social.result.Exfiltrate      21
# action.social.result.Infiltrate      15
# action.malware.result.Infiltrate     14
# action.physical.result.Infiltrate    10
# action.misuse.result.Infiltrate       5
# action.unknown.result.Infiltrate      5
# action.unknown.result.Exfiltrate      4
# action.social.result.Elevate          3
# action.malware.result.Elevate         1
# action.hacking.result.Elevate         1
# action.physical.result.Elevate        1
# Name: target, dtype: int64

# %%
target_melt(vcdb, action_vector_cols, split=False)['target'].value_counts()
# Out:
# action.error.vector.Unknown                  1301
# action.hacking.vector.Web application        1028
# action.misuse.vector.LAN access              1026
# action.error.vector.Carelessness              895
# action.hacking.vector.Unknown                 769
#                                              ...
# action.hacking.vector.3rd party desktop         2
# action.malware.vector.Software update           2
# action.physical.vector.Visitor privileges       1
# action.social.vector.IM                         1
# action.social.vector.Removable media            1
# Name: target, Length: 64, dtype: int64

# %%
vcdb[action_vector_cols].sum(axis=1).value_counts()
# Out:
# 1    6797
# 2     535
# 3     251
# 0     217
# 4      29
# 5       3
# 6       1
# dtype: int64

# %% [markdown]
# ### High Level Action
# Potentially quite useful as a target variable?
#
# i.e given properties about an organisation, what actions are most likely?

# %%
action_target_cols = [col for col in vcdb if col.startswith('action') and col.count('.')==1]
target_melt(vcdb, action_target_cols)['target'].value_counts(dropna=False)
# Out:
# Error            2266
# Hacking          2078
# Misuse           1604
# Physical         1517
# Malware           633
# Social            515
# Unknown           233
# Environmental       8
# Name: target, dtype: int64

# %% [markdown]
# ## plus

# %%
plus_cia_cols = [col for col in vcdb if col.startswith('plus.') and ('confidentiality' in col.lower() or 'integrity' in col.lower() or 'availability' in col.lower())]

# %% [markdown]
# ## Fortune 500 company

# %%
vcdb['plus.f500'].value_counts(dropna=False)
# Out:
# NaN      6751
# n         861
# u         152
# y          62
# no          5
# yes         1
# false       1
# Name: plus.f500, dtype: int64

# %%
vcdb['plus.f500'] = (
    vcdb['plus.f500']
        .fillna('u')
        .map({'y': True,
              'yes': True,
              'n': False,
              'no': False,
              'false': False,
              'u': None
             })
)

# %%
vcdb['plus.f500'].value_counts(dropna=False)
# Out:
# True     6903
# False     867
# True       63
# Name: plus.f500, dtype: int64

# %% [markdown]
# # Model 2: Predicting CIA

# %%
id_cols = [col for col in vcdb if '_id' in col]
id_cols += ['plus.github']

# %%
y_confidentiality = vcdb['attribute.Confidentiality'].values

# %%
y_integrity = vcdb['attribute.Integrity'].values

# %%
y_availability = vcdb['attribute.Availability'].values

# %%
pattern_cols
# Out:
# ['pattern.Point of Sale',
#  'pattern.Web Applications',
#  'pattern.Privilege Misuse',
#  'pattern.Lost and Stolen Assets',
#  'pattern.Miscellaneous Errors',
#  'pattern.Crimeware',
#  'pattern.Payment Card Skimmers',
#  'pattern.Denial of Service',
#  'pattern.Cyber-Espionage',
#  'pattern.Everything Else']

# %%
dropped_cols = (
    id_cols + 
    text_cols + 
    cia_cols + 
    impact_cols + 
    pattern_cols + 
    null_cols + 
    plus_cia_cols + 
    ['pattern', 'security_incident', 'plus.analyst', 'plus.analysis_status', 'schema_version', 'targeted']
)

# %%
X = (
    vcdb
        .copy()
        .drop(labels = dropped_cols, axis=1)
)
X['victim.industry2'] = X['victim.industry2'].astype(str)
assert X.select_dtypes('int64').empty
cat_cols = list(X.select_dtypes('O').columns)

# %%
X_noaction = (
    vcdb
        .copy()
        .drop(labels = dropped_cols + action_cols, axis=1)
)
X_noaction['victim.industry2'] = X_noaction['victim.industry2'].astype(str)
assert X_noaction.select_dtypes('int64').empty

# %%
X_noasset = (
    vcdb
        .copy()
        .drop(labels = dropped_cols + asset_cols, axis=1)
)
X_noasset['victim.industry2'] = X_noasset['victim.industry2'].astype(str)
assert X_noasset.select_dtypes('int64').empty

# %%
X_noactionasset = (
    vcdb
        .copy()
        .drop(labels = dropped_cols + asset_cols + action_cols, axis=1)
)
X_noactionasset['victim.industry2'] = X_noactionasset['victim.industry2'].astype(str)
assert X_noactionasset.select_dtypes('int64').empty

# %%
X_noactionasset.columns
# Out:
# Index(['control_failure', 'plus.asset_os.Android', 'plus.asset_os.Apple iOS',
#        'plus.asset_os.BlackBerry OS', 'plus.asset_os.Linux',
#        'plus.asset_os.Mac OSX', 'plus.asset_os.Mainframe',
#        'plus.asset_os.Not applicable', 'plus.asset_os.Other',
#        'plus.asset_os.Symbian', 'plus.asset_os.Unix', 'plus.asset_os.Unknown',
#        'plus.asset_os.webOS', 'plus.asset_os.Windows',
#        'plus.asset_os.Windows Phone', 'plus.asset.total',
#        'plus.event_chain.actor.ext', 'plus.event_chain.actor.int',
#        'plus.event_chain.actor.prt', 'plus.event_chain.actor.unk', 'plus.f500',
#        'plus.pci.compliance_status.Found Compliant',
#        'plus.pci.compliance_status.Not Compliant',
#        'plus.pci.compliance_status.Unknown', 'plus.pci.merchant_level.Level 1',
#        'plus.pci.merchant_level.Level 2', 'plus.pci.merchant_level.Level 3',
#        'plus.pci.merchant_level.Level 4', 'plus.pci.merchant_level.Unknown',
#        'plus.sub_source', 'victim.industry', 'victim.locations_affected',
#        'victim.region', 'victim.revenue.amount', 'victim.secondary.amount',
#        'victim.state', 'victim.industry2', 'victim.industry3',
#        'victim.industry.name', 'confidence', 'victim.employee_count',
#        'victim.country', 'victim.revenue.iso_currency_code', 'victim.orgsize',
#        'cost_corrective_action', 'plus.attack_difficulty_initial',
#        'plus.attack_difficulty_legacy', 'plus.attack_difficulty_subsequent',
#        'plus.unknown_unknowns'],
#       dtype='object')

# %% [markdown]
# ## Model Comparison

# %%
def compare_models(data, labels, exc_cols=[], title='Receiver Operating Characteristic', figsize=(8,5)):
    X_train, X_val, y_train, y_val = train_test_split(data, labels, test_size=0.2, random_state=42)
    X_train.is_copy = None
    X_val.is_copy = None
    cat_cols = list(X.select_dtypes('O').columns)

    preprocessor = Pipeline(([
        ('encoder', MEstimateEncoder(cols=[col for col in cat_cols if col not in exc_cols])),
        ('imputer', IterativeImputer(verbose=2))
    ]))
    sampler = ADASYN()

    X_train_preprocessed = preprocessor.fit_transform(X_train, y_train)
    X_val_preprocessed = preprocessor.transform(X_val)
    X_train_resampled, y_train_resampled = sampler.fit_resample(X_train_preprocessed, y_train)
    
    models = {
        'XGBoost': {
            'model': XGBClassifier(),
            'c_line' : 'b'
        },
        'Random Forest': {
            'model': RandomForestClassifier(),
            'c_line': 'g'
        },
        'SVM': {
            'model': SVC(probability=True),
            'c_line': 'm'
        },
        'Naive Bayes': {
            'model': GaussianNB(),
            'c_line': 'y'
        }
    }
    
    names = []
    roc_aucs = []
    accuracies = []
    precisions = []
    recalls = []
    f1s = []
    

    fig = plt.figure(figsize=figsize)

    for model_name, model in models.items():

        t0 = datetime.datetime.now()

        print('Fitting %s...\n'%model_name)

        clf = model['model']
        
        if model_name == 'Naive Bayes':
            scaler = MinMaxScaler()
            x_train = scaler.fit_transform(X_train_resampled)
            x_test = scaler.transform(X_val_preprocessed)
        else:
            x_train = X_train_resampled
            x_test = X_val_preprocessed
        y_train = y_train_resampled
        y_test = y_val

        clf.fit(x_train, y_train)

        print('%s Fitted!'%model_name)
        print('Total Time Elapsed - %s'%format_timedelta(datetime.datetime.now()-t0))

        print('---------------------------------------------------')
        print('Predicting on validation data...')
        y_pred_proba = clf.predict_proba(x_test)[:,1]
        y_pred = clf.predict(x_test)

        print('Predictions Completed')
        print('Total Time Elapsed - %s'%format_timedelta(datetime.datetime.now()-t0))
        print('---------------------------------------------------')
        
        names.append(model_name)
        
        roc_auc = roc_auc_score(y_test, y_pred_proba)
        roc_aucs.append(roc_auc)
#         models[model_name]['roc-auc'] = roc_auc

        accuracy = accuracy_score(y_test, y_pred)
        accuracies.append(accuracy)
#         models[model_name]['accuracy'] = accuracy

        precision = precision_score(y_test, y_pred)
        precisions.append(precision)
#         models[model_name]['precision'] = precision

        recall = recall_score(y_test, y_pred)
        recalls.append(recall)
#         models[model_name]['recall'] = recall

        f1  = f1_score(y_test, y_pred)
        f1s.append(f1)
#         models[model_name]['f1 score'] = f1


        print('ROC-AUC Score: {:.2%}'.format(roc_auc))
        print('Accuracy Score: {:.2%}'.format(accuracy))
        print('Precision Score: {:.2%}'.format(precision))
        print('Recall Score: {:.2%}'.format(recall))
        print('F1 Score: {:.2%}'.format(f1))
        print('---------------------------------------------------')
        print('Classification Report:')
        print(classification_report(y_test, y_pred))
        print('---------------------------------------------------')
        print('\nConfusion Matrix:')
        confusion = pd.DataFrame(confusion_matrix(y_test, y_pred)).loc[range(2), range(2)]
        print(confusion)
        print('\n\n===================================================')
        fpr, tpr, threshold = roc_curve(y_test, y_pred_proba)
        # fpr, tpr, threshold = roc_curve(y_val, y_pred_proba)
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, models[model_name]['c_line'], label = '%s (AUC = %0.2f)' % (model_name, roc_auc))
    
    results = pd.DataFrame({
        'Model Name': names,
        'Accuracy': accuracies,
        'Precision': precisions,
        'Recall': recalls,
        'F1 Score': f1s,
        'ROC-AUC': roc_aucs
    })
    # make the plot
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.title(title)
    plt.savefig('figs/results_figs/%s.png'%title.replace(' ', '_'))
    plt.show()
    
    return results

# %% [markdown]
# ---
# # Predicting Confidentiality

# %% [markdown]
# ### With Action Columns

# %%
confidentiality_results = compare_models(X, y_confidentiality)
# Out:
# [IterativeImputer] Completing matrix with shape (6266, 468)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 116.68
# [IterativeImputer] Change: 176365.40204378677, scaled tolerance: 130000000.0
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (1567, 468)
# [IterativeImputer] Ending imputation round 1/1, elapsed time 0.17
# Fitting XGBoost...
#
# XGBoost Fitted!
# Total Time Elapsed - 0:0:4
# ---------------------------------------------------
# Predicting on validation data...
# Predictions Completed
# Total Time Elapsed - 0:0:4
# ---------------------------------------------------
# ROC-AUC Score: 90.79%
# Accuracy Score: 94.89%
# Precision Score: 96.35%
# Recall Score: 98.21%
# F1 Score: 97.27%
# ---------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.71      0.54      0.61       117
#         True       0.96      0.98      0.97      1450
#
#     accuracy                           0.95      1567
#    macro avg       0.84      0.76      0.79      1567
# weighted avg       0.94      0.95      0.95      1567
#
# ---------------------------------------------------
#
# Confusion Matrix:
#     0     1
# 0  63    54
# 1  26  1424
#
#
# ===================================================
# Fitting Random Forest...
#
# Random Forest Fitted!
# Total Time Elapsed - 0:0:2
# ---------------------------------------------------
# Predicting on validation data...
# Predictions Completed
# Total Time Elapsed - 0:0:2
# ---------------------------------------------------
# ROC-AUC Score: 92.74%
# Accuracy Score: 94.58%
# Precision Score: 96.27%
# Recall Score: 97.93%
# F1 Score: 97.09%
# ---------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.67      0.53      0.59       117
#         True       0.96      0.98      0.97      1450
#
#     accuracy                           0.95      1567
#    macro avg       0.82      0.75      0.78      1567
# weighted avg       0.94      0.95      0.94      1567
#
# ---------------------------------------------------
#
# Confusion Matrix:
#     0     1
# 0  62    55
# 1  30  1420
#
#
# ===================================================
# Fitting SVM...
#
# SVM Fitted!
# Total Time Elapsed - 0:4:54
# ---------------------------------------------------
# Predicting on validation data...
# Predictions Completed
# Total Time Elapsed - 0:5:7
# ---------------------------------------------------
# ROC-AUC Score: 52.50%
# Accuracy Score: 13.78%
# Precision Score: 99.01%
# Recall Score: 6.90%
# F1 Score: 12.89%
# ---------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.08      0.99      0.15       117
#         True       0.99      0.07      0.13      1450
#
#     accuracy                           0.14      1567
#    macro avg       0.53      0.53      0.14      1567
# weighted avg       0.92      0.14      0.13      1567
#
# ---------------------------------------------------
#
# Confusion Matrix:
#       0    1
# 0   116    1
# 1  1350  100
#
#
# ===================================================
# Fitting Naive Bayes...
#
# Naive Bayes Fitted!
# Total Time Elapsed - 0:0:0
# ---------------------------------------------------
# Predicting on validation data...
# Predictions Completed
# Total Time Elapsed - 0:0:0
# ---------------------------------------------------
# ROC-AUC Score: 73.92%
# Accuracy Score: 43.40%
# Precision Score: 98.62%
# Recall Score: 39.38%
# F1 Score: 56.28%
# ---------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.11      0.93      0.20       117
#         True       0.99      0.39      0.56      1450
#
#     accuracy                           0.43      1567
#    macro avg       0.55      0.66      0.38      1567
# weighted avg       0.92      0.43      0.54      1567
#
# ---------------------------------------------------
#
# Confusion Matrix:
#      0    1
# 0  109    8
# 1  879  571
#
#
# ===================================================

# %% [markdown]
# ### Without Action Columns

# %%
confidentiality_noaction_results = compare_models(X_noaction, y_confidentiality, action_cols, title='Confidentiality Models ROC')
# Out:
# [IterativeImputer] Completing matrix with shape (6266, 200)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 18.46
# [IterativeImputer] Change: 210874.74090215226, scaled tolerance: 130000000.0
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (1567, 200)
# [IterativeImputer] Ending imputation round 1/1, elapsed time 0.13
# Fitting XGBoost...
#
# XGBoost Fitted!
# Total Time Elapsed - 0:0:3
# ---------------------------------------------------
# Predicting on validation data...
# Predictions Completed
# Total Time Elapsed - 0:0:3
# ---------------------------------------------------
# ROC-AUC Score: 85.69%
# Accuracy Score: 92.79%
# Precision Score: 95.20%
# Recall Score: 97.10%
# F1 Score: 96.14%
# ---------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.52      0.39      0.45       117
#         True       0.95      0.97      0.96      1450
#
#     accuracy                           0.93      1567
#    macro avg       0.74      0.68      0.71      1567
# weighted avg       0.92      0.93      0.92      1567
#
# ---------------------------------------------------
#
# Confusion Matrix:
#     0     1
# 0  46    71
# 1  42  1408
#
#
# ===================================================
# Fitting Random Forest...
#
# Random Forest Fitted!
# Total Time Elapsed - 0:0:2
# ---------------------------------------------------
# Predicting on validation data...
# Predictions Completed
# Total Time Elapsed - 0:0:2
# ---------------------------------------------------
# ROC-AUC Score: 87.59%
# Accuracy Score: 92.60%
# Precision Score: 95.50%
# Recall Score: 96.55%
# F1 Score: 96.02%
# ---------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.50      0.44      0.47       117
#         True       0.95      0.97      0.96      1450
#
#     accuracy                           0.93      1567
#    macro avg       0.73      0.70      0.71      1567
# weighted avg       0.92      0.93      0.92      1567
#
# ---------------------------------------------------
#
# Confusion Matrix:
#     0     1
# 0  51    66
# 1  50  1400
#
#
# ===================================================
# Fitting SVM...
#
# SVM Fitted!
# Total Time Elapsed - 0:2:25
# ---------------------------------------------------
# Predicting on validation data...
# Predictions Completed
# Total Time Elapsed - 0:2:31
# ---------------------------------------------------
# ROC-AUC Score: 52.36%
# Accuracy Score: 13.78%
# Precision Score: 99.01%
# Recall Score: 6.90%
# F1 Score: 12.89%
# ---------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.08      0.99      0.15       117
#         True       0.99      0.07      0.13      1450
#
#     accuracy                           0.14      1567
#    macro avg       0.53      0.53      0.14      1567
# weighted avg       0.92      0.14      0.13      1567
#
# ---------------------------------------------------
#
# Confusion Matrix:
#       0    1
# 0   116    1
# 1  1350  100
#
#
# ===================================================
# Fitting Naive Bayes...
#
# Naive Bayes Fitted!
# Total Time Elapsed - 0:0:0
# ---------------------------------------------------
# Predicting on validation data...
# Predictions Completed
# Total Time Elapsed - 0:0:0
# ---------------------------------------------------
# ROC-AUC Score: 82.16%
# Accuracy Score: 19.08%
# Precision Score: 98.40%
# Recall Score: 12.76%
# F1 Score: 22.59%
# ---------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.08      0.97      0.15       117
#         True       0.98      0.13      0.23      1450
#
#     accuracy                           0.19      1567
#    macro avg       0.53      0.55      0.19      1567
# weighted avg       0.92      0.19      0.22      1567
#
# ---------------------------------------------------
#
# Confusion Matrix:
#       0    1
# 0   114    3
# 1  1265  185
#
#
# ===================================================

# %% [markdown]
# ## Confidentiality Model Tuning

# %%
X_train, X_test, y_train, y_test = train_test_split(X_noaction, y_confidentiality, test_size=0.2, random_state=42)
# Define our Objective Function
@optunity.cross_validated(x=X_train.values, y=y_train, num_folds=3)
# @optunity.cross_validated(x=X_train_resampled, y=y_train_resampled.values, num_folds=5)
def xgb_tuned_recall(x_train, y_train, x_test, y_test, 
                     # These are the hyperparameters we wish to tune
                     n_estimators,
                     max_depth, 
                     min_child_weight, 
                     gamma, 
                     colsample_bytree,
                     subsample,
                     reg_alpha, 
                     reg_lambda):
    
    # categorical encoding
#     print('M-encoding categoricals')
    x_train_df = pd.DataFrame(x_train, columns = X_noaction.columns)
    x_test_df = pd.DataFrame(x_test, columns = X_noaction.columns)
    cat_cols = list(x_train_df.select_dtypes('O').columns)
    assert all([col in x_train_df for col in cat_cols])
    
    m_encoder = MEstimateEncoder(cols=cat_cols)
    x_train_enc = m_encoder.fit_transform(x_train_df, y_train)
    x_test_enc = m_encoder.transform(x_test_df)
    
    # imputation
#     print('Imputing nulls')
    imputer = IterativeImputer(verbose=0)
    x_train_imp = imputer.fit_transform(x_train_enc)
    x_test = imputer.transform(x_test_enc)
        
    # oversampling
#     print('Oversampling')
    oversampler = ADASYN()
    x_train, y_train = oversampler.fit_resample(x_train_imp, y_train)
    
#     print('Fitting Model')
    model = (
        # instanciate classifier every evaluation
        XGBClassifier(n_estimators = round(n_estimators), 
                      max_depth = round(max_depth),
                      min_child_weight = min_child_weight,
                      gamma = gamma,
                      colsample_bytree = colsample_bytree,
                      subsample = subsample,
                      reg_alpha = reg_alpha,
                      reg_lambda = reg_lambda,
                      verbose = 0
                     )
            # fit model
            ).fit(x_train, y_train)
    
    y_pred = model.predict(x_test)
    y_pred_proba = model.predict_proba(x_test)[:, 1]
    score = recall_score(y_test, y_pred)
    print('Recall Score= {:.2%}'.format(score), '| Total Time Elapsed - %s'%format_timedelta(datetime.datetime.now()-t0))
    return score

t0 = datetime.datetime.now()
print('Tuning XGBoost...')
print('----------------------------\n')

con_optimum, details, _ = optunity.maximize(xgb_tuned_recall, 
                                            num_evals = 100, 
                                            # define hyperparameter grid
                                            n_estimators = [100, 1000], 
                                            max_depth = [2, 10], 
                                            min_child_weight = [1, 7],
                                            gamma = [0.1, 2],
                                            colsample_bytree = [0.3, 1],
                                            subsample = [0.2, 0.7],
                                            reg_alpha = [0, 1],
                                            reg_lambda = [1, 5]
                                           )

print('Tuning Completed!')
print('Total Time Elapsed - %s'%format_timedelta(datetime.datetime.now()-t0))

con_optimum['n_estimators'] = round(con_optimum['n_estimators'])
con_optimum['max_depth'] = round(con_optimum['max_depth'])
con_optimum
# Out:
# Tuning XGBoost...
# ----------------------------
#
# Recall Score= 96.11% | Total Time Elapsed - 0:0:19
# Recall Score= 97.05% | Total Time Elapsed - 0:0:38
# Recall Score= 96.08% | Total Time Elapsed - 0:0:56
# Recall Score= 96.21% | Total Time Elapsed - 0:1:19
# Recall Score= 96.84% | Total Time Elapsed - 0:1:42
# Recall Score= 96.39% | Total Time Elapsed - 0:2:5
# Recall Score= 96.63% | Total Time Elapsed - 0:2:24
# Recall Score= 96.84% | Total Time Elapsed - 0:2:42
# Recall Score= 96.65% | Total Time Elapsed - 0:3:1
# Recall Score= 96.89% | Total Time Elapsed - 0:3:19
# Recall Score= 97.00% | Total Time Elapsed - 0:3:36
# Recall Score= 96.29% | Total Time Elapsed - 0:3:53
# Recall Score= 95.75% | Total Time Elapsed - 0:4:9
# Recall Score= 96.89% | Total Time Elapsed - 0:4:24
# Recall Score= 95.87% | Total Time Elapsed - 0:4:40
# Recall Score= 96.94% | Total Time Elapsed - 0:4:58
# Recall Score= 97.20% | Total Time Elapsed - 0:5:16
# Recall Score= 96.08% | Total Time Elapsed - 0:5:34
# Recall Score= 96.99% | Total Time Elapsed - 0:5:55
# Recall Score= 96.58% | Total Time Elapsed - 0:6:15
# Recall Score= 95.87% | Total Time Elapsed - 0:6:36
# Recall Score= 96.63% | Total Time Elapsed - 0:6:55
# Recall Score= 96.79% | Total Time Elapsed - 0:7:14
# Recall Score= 96.08% | Total Time Elapsed - 0:7:33
# Recall Score= 96.27% | Total Time Elapsed - 0:7:49
# Recall Score= 97.15% | Total Time Elapsed - 0:8:6
# Recall Score= 95.98% | Total Time Elapsed - 0:8:22
# Recall Score= 96.89% | Total Time Elapsed - 0:8:47
# Recall Score= 97.31% | Total Time Elapsed - 0:9:12
# Recall Score= 96.70% | Total Time Elapsed - 0:9:37
# Recall Score= 96.37% | Total Time Elapsed - 0:9:56
# Recall Score= 96.84% | Total Time Elapsed - 0:10:15
# Recall Score= 96.18% | Total Time Elapsed - 0:10:34
# Recall Score= 96.47% | Total Time Elapsed - 0:10:56
# Recall Score= 97.26% | Total Time Elapsed - 0:11:19
# Recall Score= 95.93% | Total Time Elapsed - 0:11:41
# Recall Score= 96.47% | Total Time Elapsed - 0:12:0
# Recall Score= 96.74% | Total Time Elapsed - 0:12:19
# Recall Score= 96.39% | Total Time Elapsed - 0:12:39
# Recall Score= 96.63% | Total Time Elapsed - 0:12:56
# Recall Score= 96.89% | Total Time Elapsed - 0:13:13
# Recall Score= 96.60% | Total Time Elapsed - 0:13:31
# Recall Score= 95.90% | Total Time Elapsed - 0:13:46
# Recall Score= 96.79% | Total Time Elapsed - 0:14:1
# Recall Score= 96.34% | Total Time Elapsed - 0:14:17
# Recall Score= 96.94% | Total Time Elapsed - 0:14:35
# Recall Score= 97.15% | Total Time Elapsed - 0:14:53
# Recall Score= 96.03% | Total Time Elapsed - 0:15:11
# Recall Score= 96.42% | Total Time Elapsed - 0:15:31
# Recall Score= 97.10% | Total Time Elapsed - 0:15:51
# Recall Score= 96.49% | Total Time Elapsed - 0:16:11
# Recall Score= 96.68% | Total Time Elapsed - 0:16:30
# Recall Score= 96.64% | Total Time Elapsed - 0:16:49
# Recall Score= 96.18% | Total Time Elapsed - 0:17:9
# Recall Score= 96.47% | Total Time Elapsed - 0:17:25
# Recall Score= 97.52% | Total Time Elapsed - 0:17:41
# Recall Score= 96.49% | Total Time Elapsed - 0:17:58
# Recall Score= 96.42% | Total Time Elapsed - 0:18:21
# Recall Score= 97.10% | Total Time Elapsed - 0:18:45
# Recall Score= 96.75% | Total Time Elapsed - 0:19:8
# Recall Score= 95.95% | Total Time Elapsed - 0:19:27
# Recall Score= 96.95% | Total Time Elapsed - 0:19:46
# Recall Score= 96.49% | Total Time Elapsed - 0:20:5
# Recall Score= 96.68% | Total Time Elapsed - 0:20:27
# Recall Score= 96.79% | Total Time Elapsed - 0:20:48
# Recall Score= 96.34% | Total Time Elapsed - 0:21:9
# Recall Score= 96.27% | Total Time Elapsed - 0:21:29
# Recall Score= 96.95% | Total Time Elapsed - 0:21:48
# Recall Score= 96.34% | Total Time Elapsed - 0:22:8
# Recall Score= 96.32% | Total Time Elapsed - 0:22:26
# Recall Score= 96.48% | Total Time Elapsed - 0:22:44
# Recall Score= 96.18% | Total Time Elapsed - 0:23:2
# Recall Score= 96.01% | Total Time Elapsed - 0:23:18
# Recall Score= 96.74% | Total Time Elapsed - 0:23:34
# Recall Score= 96.13% | Total Time Elapsed - 0:23:50
# Recall Score= 96.89% | Total Time Elapsed - 0:24:9
# Recall Score= 97.00% | Total Time Elapsed - 0:24:28
# Recall Score= 96.75% | Total Time Elapsed - 0:24:47
# Recall Score= 96.84% | Total Time Elapsed - 0:25:7
# Recall Score= 96.89% | Total Time Elapsed - 0:25:27
# Recall Score= 96.29% | Total Time Elapsed - 0:25:46
# Recall Score= 95.95% | Total Time Elapsed - 0:26:6
# Recall Score= 97.20% | Total Time Elapsed - 0:26:27
# Recall Score= 96.49% | Total Time Elapsed - 0:26:47
# Recall Score= 96.42% | Total Time Elapsed - 0:27:4
# Recall Score= 97.20% | Total Time Elapsed - 0:27:21
# Recall Score= 96.60% | Total Time Elapsed - 0:27:39
# Recall Score= 96.58% | Total Time Elapsed - 0:28:3
# Recall Score= 97.26% | Total Time Elapsed - 0:28:27
# Recall Score= 96.80% | Total Time Elapsed - 0:28:51
# Recall Score= 96.11% | Total Time Elapsed - 0:29:10
# Recall Score= 97.05% | Total Time Elapsed - 0:29:30
# Recall Score= 96.54% | Total Time Elapsed - 0:29:50
# Recall Score= 96.32% | Total Time Elapsed - 0:30:11
# Recall Score= 96.58% | Total Time Elapsed - 0:30:32
# Recall Score= 96.60% | Total Time Elapsed - 0:30:54
# Recall Score= 96.89% | Total Time Elapsed - 0:31:14
# Recall Score= 97.15% | Total Time Elapsed - 0:31:35
# Recall Score= 96.34% | Total Time Elapsed - 0:31:55
# Recall Score= 96.27% | Total Time Elapsed - 0:32:14
# Recall Score= 97.05% | Total Time Elapsed - 0:32:33
# Recall Score= 95.98% | Total Time Elapsed - 0:32:52
# Recall Score= 96.21% | Total Time Elapsed - 0:33:10
# Recall Score= 96.95% | Total Time Elapsed - 0:33:27
# Recall Score= 96.34% | Total Time Elapsed - 0:33:44
# Recall Score= 96.94% | Total Time Elapsed - 0:34:4
# Recall Score= 96.95% | Total Time Elapsed - 0:34:24
# Recall Score= 96.65% | Total Time Elapsed - 0:34:44
# Recall Score= 96.21% | Total Time Elapsed - 0:35:6
# Recall Score= 97.00% | Total Time Elapsed - 0:35:28
# Recall Score= 96.60% | Total Time Elapsed - 0:35:49
# Recall Score= 96.68% | Total Time Elapsed - 0:36:7
# Recall Score= 96.43% | Total Time Elapsed - 0:36:25
# Recall Score= 96.44% | Total Time Elapsed - 0:36:44
# Recall Score= 96.32% | Total Time Elapsed - 0:37:9
# Recall Score= 97.10% | Total Time Elapsed - 0:37:33
# Recall Score= 96.44% | Total Time Elapsed - 0:37:58
# Recall Score= 96.32% | Total Time Elapsed - 0:38:20
# Recall Score= 97.05% | Total Time Elapsed - 0:38:42
# Recall Score= 96.96% | Total Time Elapsed - 0:39:3
# Recall Score= 97.41% | Total Time Elapsed - 0:39:24
# Recall Score= 97.26% | Total Time Elapsed - 0:39:46
# Recall Score= 96.60% | Total Time Elapsed - 0:40:7
# Recall Score= 96.11% | Total Time Elapsed - 0:40:27
# Recall Score= 96.58% | Total Time Elapsed - 0:40:46
# Recall Score= 96.49% | Total Time Elapsed - 0:41:6
# Recall Score= 96.27% | Total Time Elapsed - 0:41:24
# Recall Score= 96.89% | Total Time Elapsed - 0:41:42
# Recall Score= 96.44% | Total Time Elapsed - 0:41:59
# Recall Score= 96.42% | Total Time Elapsed - 0:42:19
# Recall Score= 96.84% | Total Time Elapsed - 0:42:40
# Recall Score= 96.70% | Total Time Elapsed - 0:43:0
# Recall Score= 96.27% | Total Time Elapsed - 0:43:22
# Recall Score= 97.15% | Total Time Elapsed - 0:43:44
# Recall Score= 96.24% | Total Time Elapsed - 0:44:6
# Recall Score= 96.42% | Total Time Elapsed - 0:44:25
# Recall Score= 97.20% | Total Time Elapsed - 0:44:45
# Recall Score= 96.49% | Total Time Elapsed - 0:45:6
# Recall Score= 96.68% | Total Time Elapsed - 0:45:31
# Recall Score= 97.36% | Total Time Elapsed - 0:45:56
# Recall Score= 96.75% | Total Time Elapsed - 0:46:21
# Recall Score= 96.16% | Total Time Elapsed - 0:46:44
# Recall Score= 97.10% | Total Time Elapsed - 0:47:7
# Recall Score= 96.34% | Total Time Elapsed - 0:47:30
# Recall Score= 96.42% | Total Time Elapsed - 0:47:51
# Recall Score= 97.00% | Total Time Elapsed - 0:48:11
# Recall Score= 96.29% | Total Time Elapsed - 0:48:32
# Recall Score= 96.11% | Total Time Elapsed - 0:48:56
# Recall Score= 97.20% | Total Time Elapsed - 0:49:20
# Recall Score= 96.60% | Total Time Elapsed - 0:49:45
# Recall Score= 96.11% | Total Time Elapsed - 0:50:8
# Recall Score= 96.74% | Total Time Elapsed - 0:50:32
# Recall Score= 96.24% | Total Time Elapsed - 0:50:55
# Recall Score= 96.63% | Total Time Elapsed - 0:51:20
# Recall Score= 97.26% | Total Time Elapsed - 0:51:44
# Recall Score= 96.70% | Total Time Elapsed - 0:52:9
# Recall Score= 96.52% | Total Time Elapsed - 0:52:29
# Recall Score= 97.36% | Total Time Elapsed - 0:52:49
# Recall Score= 96.34% | Total Time Elapsed - 0:53:11
# Recall Score= 96.84% | Total Time Elapsed - 0:53:38
# Recall Score= 97.10% | Total Time Elapsed - 0:54:4
# Recall Score= 96.60% | Total Time Elapsed - 0:54:30
# Recall Score= 96.37% | Total Time Elapsed - 0:54:52
# Recall Score= 97.10% | Total Time Elapsed - 0:55:16
# Recall Score= 96.65% | Total Time Elapsed - 0:55:38
# Recall Score= 96.42% | Total Time Elapsed - 0:56:4
# Recall Score= 97.10% | Total Time Elapsed - 0:56:29
# Recall Score= 96.70% | Total Time Elapsed - 0:56:54
# Recall Score= 96.06% | Total Time Elapsed - 0:57:15
# Recall Score= 96.79% | Total Time Elapsed - 0:57:36
# Recall Score= 96.18% | Total Time Elapsed - 0:57:57
# Recall Score= 96.37% | Total Time Elapsed - 0:58:18
# Recall Score= 97.00% | Total Time Elapsed - 0:58:38
# Recall Score= 96.60% | Total Time Elapsed - 0:58:59
# Recall Score= 96.42% | Total Time Elapsed - 0:59:22
# Recall Score= 97.10% | Total Time Elapsed - 0:59:45
# Recall Score= 96.54% | Total Time Elapsed - 1:0:9
# Recall Score= 96.06% | Total Time Elapsed - 1:0:32
# Recall Score= 97.26% | Total Time Elapsed - 1:0:56
# Recall Score= 96.54% | Total Time Elapsed - 1:1:19
# Recall Score= 96.68% | Total Time Elapsed - 1:1:40
# Recall Score= 96.79% | Total Time Elapsed - 1:2:1
# Recall Score= 96.39% | Total Time Elapsed - 1:2:22
# Recall Score= 96.21% | Total Time Elapsed - 1:2:48
# Recall Score= 97.00% | Total Time Elapsed - 1:3:14
# Recall Score= 96.54% | Total Time Elapsed - 1:3:41
# Recall Score= 96.78% | Total Time Elapsed - 1:4:4
# Recall Score= 96.84% | Total Time Elapsed - 1:4:27
# Recall Score= 96.49% | Total Time Elapsed - 1:4:50
# Recall Score= 96.58% | Total Time Elapsed - 1:5:13
# Recall Score= 97.36% | Total Time Elapsed - 1:5:35
# Recall Score= 96.54% | Total Time Elapsed - 1:5:57
# Recall Score= 96.52% | Total Time Elapsed - 1:6:19
# Recall Score= 97.00% | Total Time Elapsed - 1:6:41
# Recall Score= 96.54% | Total Time Elapsed - 1:7:3
# Recall Score= 96.47% | Total Time Elapsed - 1:7:25
# Recall Score= 97.20% | Total Time Elapsed - 1:7:46
# Recall Score= 96.49% | Total Time Elapsed - 1:8:9
# Recall Score= 96.78% | Total Time Elapsed - 1:8:35
# Recall Score= 97.26% | Total Time Elapsed - 1:8:59
# Recall Score= 96.49% | Total Time Elapsed - 1:9:20
# Recall Score= 96.32% | Total Time Elapsed - 1:9:42
# Recall Score= 96.64% | Total Time Elapsed - 1:10:3
# Recall Score= 96.80% | Total Time Elapsed - 1:10:25
# Recall Score= 96.78% | Total Time Elapsed - 1:10:45
# Recall Score= 97.26% | Total Time Elapsed - 1:11:4
# Recall Score= 96.44% | Total Time Elapsed - 1:11:24
# Recall Score= 97.10% | Total Time Elapsed - 1:11:45
# Recall Score= 97.15% | Total Time Elapsed - 1:12:6
# Recall Score= 96.08% | Total Time Elapsed - 1:12:26
# Recall Score= 96.42% | Total Time Elapsed - 1:12:46
# Recall Score= 97.46% | Total Time Elapsed - 1:13:7
# Recall Score= 96.65% | Total Time Elapsed - 1:13:26
# Recall Score= 96.16% | Total Time Elapsed - 1:13:46
# Recall Score= 97.20% | Total Time Elapsed - 1:14:6
# Recall Score= 96.65% | Total Time Elapsed - 1:14:26
# Recall Score= 96.63% | Total Time Elapsed - 1:14:47
# Recall Score= 97.41% | Total Time Elapsed - 1:15:8
# Recall Score= 96.54% | Total Time Elapsed - 1:15:29
# Recall Score= 96.99% | Total Time Elapsed - 1:15:49
# Recall Score= 97.15% | Total Time Elapsed - 1:16:8
# Recall Score= 96.70% | Total Time Elapsed - 1:16:27
# Recall Score= 96.78% | Total Time Elapsed - 1:16:47
# Recall Score= 97.26% | Total Time Elapsed - 1:17:7
# Recall Score= 96.75% | Total Time Elapsed - 1:17:27
# Recall Score= 96.52% | Total Time Elapsed - 1:17:47
# Recall Score= 97.00% | Total Time Elapsed - 1:18:7
# Recall Score= 96.34% | Total Time Elapsed - 1:18:27
# Recall Score= 97.10% | Total Time Elapsed - 1:18:47
# Recall Score= 97.05% | Total Time Elapsed - 1:19:7
# Recall Score= 96.49% | Total Time Elapsed - 1:19:26
# Recall Score= 96.84% | Total Time Elapsed - 1:19:47
# Recall Score= 97.00% | Total Time Elapsed - 1:20:7
# Recall Score= 96.44% | Total Time Elapsed - 1:20:27
# Tuning Completed!
# Total Time Elapsed - 1:20:27
# {'n_estimators': 878,
#  'max_depth': 8,
#  'min_child_weight': 1.013140618517723,
#  'gamma': 1.651580078125,
#  'colsample_bytree': 0.544876953125,
#  'subsample': 0.4349707031249999,
#  'reg_alpha': 0.31271484374999997,
#  'reg_lambda': 4.006645206640389}

# %% [markdown]
# ### Evaluating Tuned Confidentiality XGBoost

# %%
X_train, X_test, y_train, y_test = train_test_split(X_noaction, y_confidentiality, test_size=0.2, random_state=42)
xgb_preprocessor = Pipeline(([
    ('encoder', MEstimateEncoder(cols=[col for col in cat_cols if col not in action_cols])),
    ('imputer', IterativeImputer(verbose=0))
]))

print('Preprocessing data...')
X_train_preprocessed = xgb_preprocessor.fit_transform(X_train, y_train)
X_test_preprocessed = xgb_preprocessor.transform(X_test)

xgb_sampler = ADASYN()
print('Resampling data...')
X_train_resampled, y_train_resampled = sampler.fit_resample(X_train_preprocessed, y_train)

print('Preprocessing Completed.')
print('----------------------------\n')
xgb = XGBClassifier(**con_optimum)
t0 = datetime.datetime.now()
print('Fitting XGBoost...')
print('----------------------------\n')
xgb.fit(X_train_resampled, y_train_resampled)

print('XGBoost Fitted!')
print('Total Time Elapsed - %s'%format_timedelta(datetime.datetime.now()-t0))

print('Predicting on validation data...')
print('----------------------------\n')
y_pred_proba = xgb.predict_proba(X_test_preprocessed)[:,1]
y_pred = xgb.predict(X_test_preprocessed)

roc_auc = roc_auc_score(y_test, y_pred_proba)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1  = f1_score(y_test, y_pred)

print('ROC-AUC Score: {:.2%}'.format(roc_auc))
print('Accuracy Score: {:.2%}'.format(accuracy))
print('Precision Score: {:.2%}'.format(precision))
print('Recall Score: {:.2%}'.format(recall))
print('F1 Score: {:.2%}'.format(f1))
print('---------------------------------------------------')
print('Classification Report:')
print(classification_report(y_test, y_pred))
print('---------------------------------------------------')
print('\nConfusion Matrix:')
confusion = pd.DataFrame(confusion_matrix(y_test, y_pred)).loc[range(2), range(2)]
print(confusion)
print('\n\n===================================================')
fpr, tpr, threshold = roc_curve(y_test, y_pred_proba)
# fpr, tpr, threshold = roc_curve(y_val, y_pred_proba)
roc_auc = auc(fpr, tpr)
# Out:
# Preprocessing data...
# Resampling data...
# Preprocessing Completed.
# ----------------------------
#
# Fitting XGBoost...
# ----------------------------
#
# XGBoost Fitted!
# Total Time Elapsed - 0:0:10
# Predicting on validation data...
# ----------------------------
#
# ROC-AUC Score: 84.96%
# Accuracy Score: 91.83%
# Precision Score: 94.72%
# Recall Score: 96.55%
# F1 Score: 95.63%
# ---------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.44      0.33      0.38       117
#         True       0.95      0.97      0.96      1450
#
#     accuracy                           0.92      1567
#    macro avg       0.69      0.65      0.67      1567
# weighted avg       0.91      0.92      0.91      1567
#
# ---------------------------------------------------
#
# Confusion Matrix:
#     0     1
# 0  39    78
# 1  50  1400
#
#
# ===================================================

# %%
# Plot Results
fig = plt.figure(figsize=(8,5))
plt.plot(fpr, tpr, 'b', label = 'Tuned XGBoost: (AUC = %0.2f)' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('Confidentiality Model: Tuned XGBoost')
plt.savefig('figs/results_figs/cia/tuned_xgb_confidentiality.png')
plt.show()

# %% [markdown]
# ### Confidentiality Interpretability (No Action)
# The summary plot combines feature importance with feature effects. Each point on the summary plot is a Shapley value for a feature and an instance. The position on the y-axis is determined by the feature and on the x-axis by the Shapley value. The color represents the value of the feature from low to high. Overlapping points are jittered in y-axis direction, so we get a sense of the distribution of the Shapley values per feature. The features are ordered according to their importance.

# %%
preprocessor = Pipeline(([
    ('encoder', MEstimateEncoder(cols=[col for col in cat_cols if col not in action_cols])),
    ('imputer', IterativeImputer(verbose=2))
]))
sampler = ADASYN()

print('Preprocessing data...')

X_preprocessed = preprocessor.fit_transform(X_noaction, y_confidentiality)

print('Resampling data...')
X_resampled, y_confidentiality_resampled = sampler.fit_resample(X_preprocessed, y_confidentiality)
# Out:
# Preprocessing data...
# [IterativeImputer] Completing matrix with shape (7833, 205)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 15.21
# [IterativeImputer] Change: 7016320.712507278, scaled tolerance: 6800000000.0
# [IterativeImputer] Early stopping criterion reached.
# Resampling data...

# %%
print('Fiting XGBoost...')
xgb_confidentiality = XGBClassifier(**con_optimum)
xgb_confidentiality.fit(X_resampled, y_confidentiality_resampled)

print('SHAP explanations...')
confidentiality_xgb_explainer = shap.TreeExplainer(xgb_confidentiality)
confidentiality_xgb_shap_values = confidentiality_xgb_explainer.shap_values(X_resampled)

plt.title('SHAP Feature Importance: XGBoost Confidentiality Model')
shap.summary_plot(confidentiality_xgb_shap_values, pd.DataFrame(X_resampled, columns=X_noaction.columns))
# Out:
# Fiting XGBoost...
# SHAP explanations...
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.

# %% [markdown]
# ---
# # Predicting Integrity

# %% [markdown]
# ### With Action Columns

# %%
integrity_results = compare_models(X, y_integrity)
# Out:
# [IterativeImputer] Completing matrix with shape (6266, 468)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 111.46
# [IterativeImputer] Change: 172046.7656216661, scaled tolerance: 130000000.0
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (1567, 468)
# [IterativeImputer] Ending imputation round 1/1, elapsed time 0.17
# Fitting XGBoost...
#
# XGBoost Fitted!
# Total Time Elapsed - 0:0:3
# ---------------------------------------------------
# Predicting on validation data...
# Predictions Completed
# Total Time Elapsed - 0:0:3
# ---------------------------------------------------
# ROC-AUC Score: 94.83%
# Accuracy Score: 91.64%
# Precision Score: 81.85%
# Recall Score: 79.71%
# F1 Score: 80.76%
# ---------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.94      0.95      0.95      1222
#         True       0.82      0.80      0.81       345
#
#     accuracy                           0.92      1567
#    macro avg       0.88      0.87      0.88      1567
# weighted avg       0.92      0.92      0.92      1567
#
# ---------------------------------------------------
#
# Confusion Matrix:
#       0    1
# 0  1161   61
# 1    70  275
#
#
# ===================================================
# Fitting Random Forest...
#
# Random Forest Fitted!
# Total Time Elapsed - 0:0:1
# ---------------------------------------------------
# Predicting on validation data...
# Predictions Completed
# Total Time Elapsed - 0:0:1
# ---------------------------------------------------
# ROC-AUC Score: 95.06%
# Accuracy Score: 90.87%
# Precision Score: 78.69%
# Recall Score: 80.29%
# F1 Score: 79.48%
# ---------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.94      0.94      0.94      1222
#         True       0.79      0.80      0.79       345
#
#     accuracy                           0.91      1567
#    macro avg       0.87      0.87      0.87      1567
# weighted avg       0.91      0.91      0.91      1567
#
# ---------------------------------------------------
#
# Confusion Matrix:
#       0    1
# 0  1147   75
# 1    68  277
#
#
# ===================================================
# Fitting SVM...
#
# SVM Fitted!
# Total Time Elapsed - 0:3:21
# ---------------------------------------------------
# Predicting on validation data...
# Predictions Completed
# Total Time Elapsed - 0:3:32
# ---------------------------------------------------
# ROC-AUC Score: 49.50%
# Accuracy Score: 74.28%
# Precision Score: 21.00%
# Recall Score: 6.09%
# F1 Score: 9.44%
# ---------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.78      0.94      0.85      1222
#         True       0.21      0.06      0.09       345
#
#     accuracy                           0.74      1567
#    macro avg       0.49      0.50      0.47      1567
# weighted avg       0.65      0.74      0.68      1567
#
# ---------------------------------------------------
#
# Confusion Matrix:
#       0   1
# 0  1143  79
# 1   324  21
#
#
# ===================================================
# Fitting Naive Bayes...
#
# Naive Bayes Fitted!
# Total Time Elapsed - 0:0:0
# ---------------------------------------------------
# Predicting on validation data...
# Predictions Completed
# Total Time Elapsed - 0:0:0
# ---------------------------------------------------
# ROC-AUC Score: 92.66%
# Accuracy Score: 90.30%
# Precision Score: 91.77%
# Recall Score: 61.45%
# F1 Score: 73.61%
# ---------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.90      0.98      0.94      1222
#         True       0.92      0.61      0.74       345
#
#     accuracy                           0.90      1567
#    macro avg       0.91      0.80      0.84      1567
# weighted avg       0.90      0.90      0.90      1567
#
# ---------------------------------------------------
#
# Confusion Matrix:
#       0    1
# 0  1203   19
# 1   133  212
#
#
# ===================================================

# %% [markdown]
# ### Without Action Columns

# %%
integrity_noaction_results = compare_models(X_noaction, y_integrity, action_cols, title='Integrity Models ROC')
# Out:
# [IterativeImputer] Completing matrix with shape (6266, 200)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 11.10
# [IterativeImputer] Change: 210574.10661685013, scaled tolerance: 130000000.0
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (1567, 200)
# [IterativeImputer] Ending imputation round 1/1, elapsed time 0.07
# Fitting XGBoost...
#
# XGBoost Fitted!
# Total Time Elapsed - 0:0:1
# ---------------------------------------------------
# Predicting on validation data...
# Predictions Completed
# Total Time Elapsed - 0:0:1
# ---------------------------------------------------
# ROC-AUC Score: 85.65%
# Accuracy Score: 84.62%
# Precision Score: 66.46%
# Recall Score: 60.87%
# F1 Score: 63.54%
# ---------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.89      0.91      0.90      1222
#         True       0.66      0.61      0.64       345
#
#     accuracy                           0.85      1567
#    macro avg       0.78      0.76      0.77      1567
# weighted avg       0.84      0.85      0.84      1567
#
# ---------------------------------------------------
#
# Confusion Matrix:
#       0    1
# 0  1116  106
# 1   135  210
#
#
# ===================================================
# Fitting Random Forest...
#
# Random Forest Fitted!
# Total Time Elapsed - 0:0:1
# ---------------------------------------------------
# Predicting on validation data...
# Predictions Completed
# Total Time Elapsed - 0:0:1
# ---------------------------------------------------
# ROC-AUC Score: 87.40%
# Accuracy Score: 83.85%
# Precision Score: 62.85%
# Recall Score: 65.22%
# F1 Score: 64.01%
# ---------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.90      0.89      0.90      1222
#         True       0.63      0.65      0.64       345
#
#     accuracy                           0.84      1567
#    macro avg       0.76      0.77      0.77      1567
# weighted avg       0.84      0.84      0.84      1567
#
# ---------------------------------------------------
#
# Confusion Matrix:
#       0    1
# 0  1089  133
# 1   120  225
#
#
# ===================================================
# Fitting SVM...
#
# SVM Fitted!
# Total Time Elapsed - 0:1:10
# ---------------------------------------------------
# Predicting on validation data...
# Predictions Completed
# Total Time Elapsed - 0:1:14
# ---------------------------------------------------
# ROC-AUC Score: 49.66%
# Accuracy Score: 77.86%
# Precision Score: 33.33%
# Recall Score: 0.58%
# F1 Score: 1.14%
# ---------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.78      1.00      0.88      1222
#         True       0.33      0.01      0.01       345
#
#     accuracy                           0.78      1567
#    macro avg       0.56      0.50      0.44      1567
# weighted avg       0.68      0.78      0.69      1567
#
# ---------------------------------------------------
#
# Confusion Matrix:
#       0  1
# 0  1218  4
# 1   343  2
#
#
# ===================================================
# Fitting Naive Bayes...
#
# Naive Bayes Fitted!
# Total Time Elapsed - 0:0:0
# ---------------------------------------------------
# Predicting on validation data...
# Predictions Completed
# Total Time Elapsed - 0:0:0
# ---------------------------------------------------
# ROC-AUC Score: 57.70%
# Accuracy Score: 31.97%
# Precision Score: 24.27%
# Recall Score: 98.55%
# F1 Score: 38.95%
# ---------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.97      0.13      0.23      1222
#         True       0.24      0.99      0.39       345
#
#     accuracy                           0.32      1567
#    macro avg       0.61      0.56      0.31      1567
# weighted avg       0.81      0.32      0.27      1567
#
# ---------------------------------------------------
#
# Confusion Matrix:
#      0     1
# 0  161  1061
# 1    5   340
#
#
# ===================================================

# %% [markdown]
# ## Integrity Model Tuning

# %%
X_train, X_test, y_train, y_test = train_test_split(X_noaction, y_integrity, test_size=0.2, random_state=42)
# Define our Objective Function
@optunity.cross_validated(x=X_train.values, y=y_train, num_folds=3)
# @optunity.cross_validated(x=X_train_resampled, y=y_train_resampled.values, num_folds=5)
def xgb_tuned_recall(x_train, y_train, x_test, y_test, 
                     # These are the hyperparameters we wish to tune
                     n_estimators,
                     max_depth, 
                     min_child_weight, 
                     gamma, 
                     colsample_bytree,
                     subsample,
                     reg_alpha, 
                     reg_lambda):
    
    # categorical encoding
#     print('M-encoding categoricals')
    x_train_df = pd.DataFrame(x_train, columns = X_noaction.columns)
    x_test_df = pd.DataFrame(x_test, columns = X_noaction.columns)
    cat_cols = list(x_train_df.select_dtypes('O').columns)
    assert all([col in x_train_df for col in cat_cols])
    
    m_encoder = MEstimateEncoder(cols=cat_cols)
    x_train_enc = m_encoder.fit_transform(x_train_df, y_train)
    x_test_enc = m_encoder.transform(x_test_df)
    
    # imputation
#     print('Imputing nulls')
    imputer = IterativeImputer(verbose=0)
    x_train_imp = imputer.fit_transform(x_train_enc)
    x_test = imputer.transform(x_test_enc)
        
    # oversampling
#     print('Oversampling')
    oversampler = ADASYN()
    x_train, y_train = oversampler.fit_resample(x_train_imp, y_train)
    
#     print('Fitting Model')
    model = (
        # instanciate classifier every evaluation
        XGBClassifier(n_estimators = round(n_estimators), 
                      max_depth = round(max_depth),
                      min_child_weight = min_child_weight,
                      gamma = gamma,
                      colsample_bytree = colsample_bytree,
                      subsample = subsample,
                      reg_alpha = reg_alpha,
                      reg_lambda = reg_lambda,
                      verbose = 0
                     )
            # fit model
            ).fit(x_train, y_train)
    
    y_pred = model.predict(x_test)
    y_pred_proba = model.predict_proba(x_test)[:, 1]
    score = recall_score(y_test, y_pred)
    print('Recall Score= {:.2%}'.format(score), '| Total Time Elapsed - %s'%format_timedelta(datetime.datetime.now()-t0))
    return score

t0 = datetime.datetime.now()
print('Tuning XGBoost...')
print('----------------------------\n')

int_optimum, details, _ = optunity.maximize(xgb_tuned_recall, 
                                            num_evals = 100, 
                                            # define hyperparameter grid
                                            n_estimators = [100, 1000], 
                                            max_depth = [2, 10], 
                                            min_child_weight = [1, 7],
                                            gamma = [0.1, 2],
                                            colsample_bytree = [0.3, 1],
                                            subsample = [0.2, 0.7],
                                            reg_alpha = [0, 1],
                                            reg_lambda = [1, 5]
                                           )

print('Tuning Completed!')
print('Total Time Elapsed - %s'%format_timedelta(datetime.datetime.now()-t0))

int_optimum['n_estimators'] = round(int_optimum['n_estimators'])
int_optimum['max_depth'] = round(int_optimum['max_depth'])
int_optimum
# Out:
# Tuning XGBoost...
# ----------------------------
#
# Recall Score= 59.48% | Total Time Elapsed - 0:0:19
# Recall Score= 58.58% | Total Time Elapsed - 0:0:42
# Recall Score= 61.63% | Total Time Elapsed - 0:1:4
# Recall Score= 62.30% | Total Time Elapsed - 0:1:22
# Recall Score= 60.25% | Total Time Elapsed - 0:1:41
# Recall Score= 62.02% | Total Time Elapsed - 0:1:59
# Recall Score= 60.48% | Total Time Elapsed - 0:2:15
# Recall Score= 61.30% | Total Time Elapsed - 0:2:31
# Recall Score= 61.05% | Total Time Elapsed - 0:2:47
# Recall Score= 58.67% | Total Time Elapsed - 0:3:2
# Recall Score= 59.41% | Total Time Elapsed - 0:3:18
# Recall Score= 60.08% | Total Time Elapsed - 0:3:34
# Recall Score= 60.69% | Total Time Elapsed - 0:3:55
# Recall Score= 59.83% | Total Time Elapsed - 0:4:16
# Recall Score= 62.40% | Total Time Elapsed - 0:4:37
# Recall Score= 60.69% | Total Time Elapsed - 0:4:54
# Recall Score= 60.67% | Total Time Elapsed - 0:5:12
# Recall Score= 62.79% | Total Time Elapsed - 0:5:30
# Recall Score= 59.07% | Total Time Elapsed - 0:5:46
# Recall Score= 60.67% | Total Time Elapsed - 0:6:3
# Recall Score= 61.63% | Total Time Elapsed - 0:6:19
# Recall Score= 63.31% | Total Time Elapsed - 0:6:34
# Recall Score= 60.46% | Total Time Elapsed - 0:6:50
# Recall Score= 60.47% | Total Time Elapsed - 0:7:5
# Recall Score= 61.90% | Total Time Elapsed - 0:7:23
# Recall Score= 60.67% | Total Time Elapsed - 0:7:40
# Recall Score= 60.27% | Total Time Elapsed - 0:7:58
# Recall Score= 59.68% | Total Time Elapsed - 0:8:15
# Recall Score= 61.51% | Total Time Elapsed - 0:8:32
# Recall Score= 61.63% | Total Time Elapsed - 0:8:48
# Recall Score= 59.48% | Total Time Elapsed - 0:9:8
# Recall Score= 59.00% | Total Time Elapsed - 0:9:28
# Recall Score= 61.82% | Total Time Elapsed - 0:9:47
# Recall Score= 61.49% | Total Time Elapsed - 0:10:4
# Recall Score= 61.72% | Total Time Elapsed - 0:10:22
# Recall Score= 62.40% | Total Time Elapsed - 0:10:39
# Recall Score= 59.88% | Total Time Elapsed - 0:10:54
# Recall Score= 59.00% | Total Time Elapsed - 0:11:9
# Recall Score= 61.63% | Total Time Elapsed - 0:11:24
# Recall Score= 61.49% | Total Time Elapsed - 0:11:39
# Recall Score= 56.49% | Total Time Elapsed - 0:11:54
# Recall Score= 59.50% | Total Time Elapsed - 0:12:9
# Recall Score= 59.07% | Total Time Elapsed - 0:12:30
# Recall Score= 60.88% | Total Time Elapsed - 0:12:52
# Recall Score= 62.21% | Total Time Elapsed - 0:13:13
# Recall Score= 59.68% | Total Time Elapsed - 0:13:30
# Recall Score= 60.46% | Total Time Elapsed - 0:13:48
# Recall Score= 60.85% | Total Time Elapsed - 0:14:6
# Recall Score= 59.88% | Total Time Elapsed - 0:14:22
# Recall Score= 59.62% | Total Time Elapsed - 0:14:39
# Recall Score= 61.05% | Total Time Elapsed - 0:14:55
# Recall Score= 61.69% | Total Time Elapsed - 0:15:11
# Recall Score= 61.30% | Total Time Elapsed - 0:15:27
# Recall Score= 61.43% | Total Time Elapsed - 0:15:43
# Recall Score= 59.48% | Total Time Elapsed - 0:16:1
# Recall Score= 60.67% | Total Time Elapsed - 0:16:19
# Recall Score= 62.98% | Total Time Elapsed - 0:16:36
# Recall Score= 61.09% | Total Time Elapsed - 0:16:53
# Recall Score= 61.30% | Total Time Elapsed - 0:17:10
# Recall Score= 60.27% | Total Time Elapsed - 0:17:27
# Recall Score= 59.07% | Total Time Elapsed - 0:17:47
# Recall Score= 59.83% | Total Time Elapsed - 0:18:7
# Recall Score= 62.98% | Total Time Elapsed - 0:18:27
# Recall Score= 61.09% | Total Time Elapsed - 0:18:42
# Recall Score= 61.51% | Total Time Elapsed - 0:18:58
# Recall Score= 60.27% | Total Time Elapsed - 0:19:14
# Recall Score= 59.88% | Total Time Elapsed - 0:19:29
# Recall Score= 59.00% | Total Time Elapsed - 0:19:44
# Recall Score= 61.05% | Total Time Elapsed - 0:20:0
# Recall Score= 61.29% | Total Time Elapsed - 0:20:20
# Recall Score= 60.46% | Total Time Elapsed - 0:20:40
# Recall Score= 60.47% | Total Time Elapsed - 0:21:1
# Recall Score= 60.89% | Total Time Elapsed - 0:21:18
# Recall Score= 60.25% | Total Time Elapsed - 0:21:35
# Recall Score= 61.05% | Total Time Elapsed - 0:21:53
# Recall Score= 59.88% | Total Time Elapsed - 0:22:9
# Recall Score= 59.83% | Total Time Elapsed - 0:22:26
# Recall Score= 62.40% | Total Time Elapsed - 0:22:44
# Recall Score= 61.49% | Total Time Elapsed - 0:23:1
# Recall Score= 62.13% | Total Time Elapsed - 0:23:18
# Recall Score= 62.40% | Total Time Elapsed - 0:23:35
# Recall Score= 61.69% | Total Time Elapsed - 0:23:52
# Recall Score= 60.25% | Total Time Elapsed - 0:24:9
# Recall Score= 61.24% | Total Time Elapsed - 0:24:27
# Recall Score= 60.08% | Total Time Elapsed - 0:24:47
# Recall Score= 59.41% | Total Time Elapsed - 0:25:7
# Recall Score= 61.24% | Total Time Elapsed - 0:25:27
# Recall Score= 61.49% | Total Time Elapsed - 0:25:45
# Recall Score= 60.88% | Total Time Elapsed - 0:26:3
# Recall Score= 62.60% | Total Time Elapsed - 0:26:20
# Recall Score= 61.29% | Total Time Elapsed - 0:26:37
# Recall Score= 59.41% | Total Time Elapsed - 0:26:53
# Recall Score= 61.82% | Total Time Elapsed - 0:27:10
# Recall Score= 61.09% | Total Time Elapsed - 0:27:26
# Recall Score= 59.00% | Total Time Elapsed - 0:27:42
# Recall Score= 62.02% | Total Time Elapsed - 0:27:58
# Recall Score= 58.87% | Total Time Elapsed - 0:28:19
# Recall Score= 60.04% | Total Time Elapsed - 0:28:39
# Recall Score= 62.40% | Total Time Elapsed - 0:29:0
# Recall Score= 59.27% | Total Time Elapsed - 0:29:18
# Recall Score= 60.25% | Total Time Elapsed - 0:29:36
# Recall Score= 60.85% | Total Time Elapsed - 0:29:54
# Recall Score= 59.07% | Total Time Elapsed - 0:30:12
# Recall Score= 60.88% | Total Time Elapsed - 0:30:29
# Recall Score= 61.82% | Total Time Elapsed - 0:30:47
# Recall Score= 61.49% | Total Time Elapsed - 0:31:4
# Recall Score= 61.30% | Total Time Elapsed - 0:31:22
# Recall Score= 63.18% | Total Time Elapsed - 0:31:39
# Recall Score= 60.48% | Total Time Elapsed - 0:31:57
# Recall Score= 58.58% | Total Time Elapsed - 0:32:15
# Recall Score= 62.21% | Total Time Elapsed - 0:32:32
# Recall Score= 62.30% | Total Time Elapsed - 0:32:50
# Recall Score= 60.88% | Total Time Elapsed - 0:33:8
# Recall Score= 62.02% | Total Time Elapsed - 0:33:26
# Recall Score= 59.07% | Total Time Elapsed - 0:33:46
# Recall Score= 60.25% | Total Time Elapsed - 0:34:7
# Recall Score= 60.47% | Total Time Elapsed - 0:34:28
# Recall Score= 61.49% | Total Time Elapsed - 0:34:45
# Recall Score= 61.30% | Total Time Elapsed - 0:35:3
# Recall Score= 62.79% | Total Time Elapsed - 0:35:20
# Recall Score= 62.70% | Total Time Elapsed - 0:35:37
# Recall Score= 59.83% | Total Time Elapsed - 0:35:55
# Recall Score= 61.43% | Total Time Elapsed - 0:36:12
# Recall Score= 60.28% | Total Time Elapsed - 0:36:29
# Recall Score= 60.67% | Total Time Elapsed - 0:36:46
# Recall Score= 61.82% | Total Time Elapsed - 0:37:3
# Recall Score= 61.09% | Total Time Elapsed - 0:37:23
# Recall Score= 58.58% | Total Time Elapsed - 0:37:44
# Recall Score= 62.98% | Total Time Elapsed - 0:38:5
# Recall Score= 61.69% | Total Time Elapsed - 0:38:23
# Recall Score= 60.25% | Total Time Elapsed - 0:38:41
# Recall Score= 62.21% | Total Time Elapsed - 0:38:59
# Recall Score= 60.69% | Total Time Elapsed - 0:39:16
# Recall Score= 60.67% | Total Time Elapsed - 0:39:34
# Recall Score= 63.57% | Total Time Elapsed - 0:39:52
# Recall Score= 59.88% | Total Time Elapsed - 0:40:10
# Recall Score= 59.83% | Total Time Elapsed - 0:40:28
# Recall Score= 62.02% | Total Time Elapsed - 0:40:46
# Recall Score= 60.89% | Total Time Elapsed - 0:41:4
# Recall Score= 61.30% | Total Time Elapsed - 0:41:22
# Recall Score= 62.79% | Total Time Elapsed - 0:41:40
# Recall Score= 60.89% | Total Time Elapsed - 0:41:56
# Recall Score= 60.67% | Total Time Elapsed - 0:42:14
# Recall Score= 61.43% | Total Time Elapsed - 0:42:32
# Recall Score= 60.08% | Total Time Elapsed - 0:42:53
# Recall Score= 60.46% | Total Time Elapsed - 0:43:14
# Recall Score= 63.18% | Total Time Elapsed - 0:43:36
# Recall Score= 62.90% | Total Time Elapsed - 0:43:54
# Recall Score= 59.83% | Total Time Elapsed - 0:44:12
# Recall Score= 62.60% | Total Time Elapsed - 0:44:29
# Recall Score= 60.69% | Total Time Elapsed - 0:44:47
# Recall Score= 59.21% | Total Time Elapsed - 0:45:6
# Recall Score= 59.50% | Total Time Elapsed - 0:45:24
# Recall Score= 62.30% | Total Time Elapsed - 0:45:40
# Recall Score= 58.58% | Total Time Elapsed - 0:45:57
# Recall Score= 61.43% | Total Time Elapsed - 0:46:14
# Recall Score= 59.27% | Total Time Elapsed - 0:46:34
# Recall Score= 59.41% | Total Time Elapsed - 0:46:53
# Recall Score= 61.43% | Total Time Elapsed - 0:47:14
# Recall Score= 60.28% | Total Time Elapsed - 0:47:33
# Recall Score= 62.13% | Total Time Elapsed - 0:47:52
# Recall Score= 61.82% | Total Time Elapsed - 0:48:12
# Recall Score= 61.29% | Total Time Elapsed - 0:48:31
# Recall Score= 61.51% | Total Time Elapsed - 0:48:51
# Recall Score= 62.21% | Total Time Elapsed - 0:49:9
# Recall Score= 60.08% | Total Time Elapsed - 0:49:28
# Recall Score= 61.72% | Total Time Elapsed - 0:49:47
# Recall Score= 60.85% | Total Time Elapsed - 0:50:7
# Recall Score= 62.10% | Total Time Elapsed - 0:50:26
# Recall Score= 60.46% | Total Time Elapsed - 0:50:45
# Recall Score= 61.63% | Total Time Elapsed - 0:51:3
# Recall Score= 61.69% | Total Time Elapsed - 0:51:20
# Recall Score= 60.67% | Total Time Elapsed - 0:51:37
# Recall Score= 62.02% | Total Time Elapsed - 0:51:55
# Recall Score= 59.48% | Total Time Elapsed - 0:52:14
# Recall Score= 60.88% | Total Time Elapsed - 0:52:34
# Recall Score= 63.18% | Total Time Elapsed - 0:52:54
# Recall Score= 62.30% | Total Time Elapsed - 0:53:11
# Recall Score= 60.67% | Total Time Elapsed - 0:53:28
# Recall Score= 61.82% | Total Time Elapsed - 0:53:47
# Recall Score= 60.69% | Total Time Elapsed - 0:54:8
# Recall Score= 61.92% | Total Time Elapsed - 0:54:28
# Recall Score= 63.95% | Total Time Elapsed - 0:54:48
# Recall Score= 61.09% | Total Time Elapsed - 0:55:6
# Recall Score= 60.25% | Total Time Elapsed - 0:55:23
# Recall Score= 62.02% | Total Time Elapsed - 0:55:41
# Recall Score= 61.90% | Total Time Elapsed - 0:56:0
# Recall Score= 60.04% | Total Time Elapsed - 0:56:19
# Recall Score= 61.43% | Total Time Elapsed - 0:56:38
# Recall Score= 60.89% | Total Time Elapsed - 0:56:56
# Recall Score= 60.25% | Total Time Elapsed - 0:57:15
# Recall Score= 62.98% | Total Time Elapsed - 0:57:34
# Recall Score= 60.69% | Total Time Elapsed - 0:57:52
# Recall Score= 59.00% | Total Time Elapsed - 0:58:11
# Recall Score= 62.21% | Total Time Elapsed - 0:58:30
# Recall Score= 61.90% | Total Time Elapsed - 0:58:47
# Recall Score= 63.39% | Total Time Elapsed - 0:59:5
# Recall Score= 60.66% | Total Time Elapsed - 0:59:23
# Recall Score= 61.09% | Total Time Elapsed - 0:59:41
# Recall Score= 60.88% | Total Time Elapsed - 0:59:59
# Recall Score= 62.21% | Total Time Elapsed - 1:0:18
# Recall Score= 60.69% | Total Time Elapsed - 1:0:38
# Recall Score= 60.46% | Total Time Elapsed - 1:0:59
# Recall Score= 60.85% | Total Time Elapsed - 1:1:19
# Recall Score= 59.88% | Total Time Elapsed - 1:1:42
# Recall Score= 59.00% | Total Time Elapsed - 1:2:4
# Recall Score= 61.43% | Total Time Elapsed - 1:2:26
# Recall Score= 61.49% | Total Time Elapsed - 1:2:47
# Recall Score= 60.67% | Total Time Elapsed - 1:3:8
# Recall Score= 62.60% | Total Time Elapsed - 1:3:29
# Recall Score= 61.29% | Total Time Elapsed - 1:3:51
# Recall Score= 60.04% | Total Time Elapsed - 1:4:13
# Recall Score= 61.63% | Total Time Elapsed - 1:4:35
# Recall Score= 60.69% | Total Time Elapsed - 1:4:55
# Recall Score= 60.46% | Total Time Elapsed - 1:5:16
# Recall Score= 61.82% | Total Time Elapsed - 1:5:37
# Recall Score= 61.29% | Total Time Elapsed - 1:5:59
# Recall Score= 59.21% | Total Time Elapsed - 1:6:20
# Recall Score= 60.47% | Total Time Elapsed - 1:6:39
# Recall Score= 60.48% | Total Time Elapsed - 1:6:57
# Recall Score= 59.41% | Total Time Elapsed - 1:7:16
# Recall Score= 62.21% | Total Time Elapsed - 1:7:35
# Recall Score= 62.30% | Total Time Elapsed - 1:7:54
# Recall Score= 60.04% | Total Time Elapsed - 1:8:13
# Recall Score= 62.79% | Total Time Elapsed - 1:8:32
# Recall Score= 62.50% | Total Time Elapsed - 1:8:49
# Recall Score= 60.88% | Total Time Elapsed - 1:9:6
# Recall Score= 60.85% | Total Time Elapsed - 1:9:23
# Recall Score= 61.29% | Total Time Elapsed - 1:9:40
# Recall Score= 61.30% | Total Time Elapsed - 1:9:57
# Recall Score= 62.21% | Total Time Elapsed - 1:10:15
# Recall Score= 59.48% | Total Time Elapsed - 1:10:33
# Recall Score= 60.88% | Total Time Elapsed - 1:10:52
# Recall Score= 61.43% | Total Time Elapsed - 1:11:10
# Recall Score= 61.69% | Total Time Elapsed - 1:11:28
# Recall Score= 60.25% | Total Time Elapsed - 1:11:46
# Recall Score= 62.02% | Total Time Elapsed - 1:12:5
# Recall Score= 61.09% | Total Time Elapsed - 1:12:23
# Recall Score= 61.51% | Total Time Elapsed - 1:12:42
# Recall Score= 61.24% | Total Time Elapsed - 1:13:0
# Recall Score= 61.09% | Total Time Elapsed - 1:13:18
# Recall Score= 60.67% | Total Time Elapsed - 1:13:36
# Recall Score= 60.08% | Total Time Elapsed - 1:13:54
# Recall Score= 60.48% | Total Time Elapsed - 1:14:13
# Recall Score= 61.92% | Total Time Elapsed - 1:14:31
# Recall Score= 62.21% | Total Time Elapsed - 1:14:49
# Recall Score= 61.90% | Total Time Elapsed - 1:15:8
# Recall Score= 61.09% | Total Time Elapsed - 1:15:26
# Recall Score= 60.85% | Total Time Elapsed - 1:15:44
# Recall Score= 61.90% | Total Time Elapsed - 1:16:3
# Recall Score= 60.46% | Total Time Elapsed - 1:16:21
# Recall Score= 60.85% | Total Time Elapsed - 1:16:39
# Recall Score= 61.69% | Total Time Elapsed - 1:16:56
# Recall Score= 60.04% | Total Time Elapsed - 1:17:14
# Recall Score= 62.21% | Total Time Elapsed - 1:17:31
# Recall Score= 59.27% | Total Time Elapsed - 1:17:48
# Recall Score= 62.55% | Total Time Elapsed - 1:18:5
# Recall Score= 63.18% | Total Time Elapsed - 1:18:21
# Recall Score= 60.08% | Total Time Elapsed - 1:18:39
# Recall Score= 59.00% | Total Time Elapsed - 1:18:56
# Recall Score= 62.40% | Total Time Elapsed - 1:19:13
# Recall Score= 59.48% | Total Time Elapsed - 1:19:30
# Recall Score= 59.83% | Total Time Elapsed - 1:19:47
# Recall Score= 61.63% | Total Time Elapsed - 1:20:5
# Recall Score= 60.89% | Total Time Elapsed - 1:20:22
# Recall Score= 62.13% | Total Time Elapsed - 1:20:41
# Recall Score= 61.24% | Total Time Elapsed - 1:21:4
# Recall Score= 61.29% | Total Time Elapsed - 1:21:34
# Recall Score= 60.67% | Total Time Elapsed - 1:22:4
# Recall Score= 63.37% | Total Time Elapsed - 1:22:35
# Recall Score= 61.69% | Total Time Elapsed - 1:23:7
# Recall Score= 60.88% | Total Time Elapsed - 1:23:37
# Recall Score= 62.02% | Total Time Elapsed - 1:24:17
# Recall Score= 61.09% | Total Time Elapsed - 1:24:58
# Recall Score= 61.51% | Total Time Elapsed - 1:25:30
# Recall Score= 61.24% | Total Time Elapsed - 1:26:1
# Recall Score= 61.90% | Total Time Elapsed - 1:26:33
# Recall Score= 59.83% | Total Time Elapsed - 1:27:5
# Recall Score= 62.02% | Total Time Elapsed - 1:27:33
# Recall Score= 62.50% | Total Time Elapsed - 1:28:30
# Recall Score= 60.67% | Total Time Elapsed - 1:29:1
# Recall Score= 61.24% | Total Time Elapsed - 1:29:30
# Recall Score= 58.87% | Total Time Elapsed - 1:29:59
# Recall Score= 60.25% | Total Time Elapsed - 1:30:29
# Recall Score= 63.18% | Total Time Elapsed - 1:30:59
# Recall Score= 60.89% | Total Time Elapsed - 1:31:22
# Recall Score= 58.37% | Total Time Elapsed - 1:32:11
# Recall Score= 61.63% | Total Time Elapsed - 1:32:31
# Tuning Completed!
# Total Time Elapsed - 1:32:31
# {'n_estimators': 603,
#  'max_depth': 4,
#  'min_child_weight': 3.5300905274546652,
#  'gamma': 0.512089936369362,
#  'colsample_bytree': 0.8869199218750002,
#  'subsample': 0.46346679687499986,
#  'reg_alpha': 0.2566911968242166,
#  'reg_lambda': 3.1822502561786017}

# %% [markdown]
# ### Evaluating Tuned Integrity XGBoost

# %%
X_train, X_test, y_train, y_test = train_test_split(X_noaction, y_integrity, test_size=0.2, random_state=42)
xgb_preprocessor = Pipeline(([
    ('encoder', MEstimateEncoder(cols=[col for col in cat_cols if col not in action_cols])),
    ('imputer', IterativeImputer(verbose=0))
]))

print('Preprocessing data...')
X_train_preprocessed = xgb_preprocessor.fit_transform(X_train, y_train)
X_test_preprocessed = xgb_preprocessor.transform(X_test)

xgb_sampler = ADASYN()
print('Resampling data...')
X_train_resampled, y_train_resampled = sampler.fit_resample(X_train_preprocessed, y_train)

print('Preprocessing Completed.')
print('----------------------------\n')
xgb = XGBClassifier(**con_optimum)
t0 = datetime.datetime.now()
print('Fitting XGBoost...')
print('----------------------------\n')
xgb.fit(X_train_resampled, y_train_resampled)

print('XGBoost Fitted!')
print('Total Time Elapsed - %s'%format_timedelta(datetime.datetime.now()-t0))

print('Predicting on validation data...')
print('----------------------------\n')
y_pred_proba = xgb.predict_proba(X_test_preprocessed)[:,1]
y_pred = xgb.predict(X_test_preprocessed)

roc_auc = roc_auc_score(y_test, y_pred_proba)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1  = f1_score(y_test, y_pred)

print('ROC-AUC Score: {:.2%}'.format(roc_auc))
print('Accuracy Score: {:.2%}'.format(accuracy))
print('Precision Score: {:.2%}'.format(precision))
print('Recall Score: {:.2%}'.format(recall))
print('F1 Score: {:.2%}'.format(f1))
print('---------------------------------------------------')
print('Classification Report:')
print(classification_report(y_test, y_pred))
print('---------------------------------------------------')
print('\nConfusion Matrix:')
confusion = pd.DataFrame(confusion_matrix(y_test, y_pred)).loc[range(2), range(2)]
print(confusion)
print('\n\n===================================================')
fpr, tpr, threshold = roc_curve(y_test, y_pred_proba)
# fpr, tpr, threshold = roc_curve(y_val, y_pred_proba)
roc_auc = auc(fpr, tpr)
# Out:
# Preprocessing data...
# Resampling data...
# Preprocessing Completed.
# ----------------------------
#
# Fitting XGBoost...
# ----------------------------
#
# XGBoost Fitted!
# Total Time Elapsed - 0:0:10
# Predicting on validation data...
# ----------------------------
#
# ROC-AUC Score: 84.96%
# Accuracy Score: 91.83%
# Precision Score: 94.72%
# Recall Score: 96.55%
# F1 Score: 95.63%
# ---------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.44      0.33      0.38       117
#         True       0.95      0.97      0.96      1450
#
#     accuracy                           0.92      1567
#    macro avg       0.69      0.65      0.67      1567
# weighted avg       0.91      0.92      0.91      1567
#
# ---------------------------------------------------
#
# Confusion Matrix:
#     0     1
# 0  39    78
# 1  50  1400
#
#
# ===================================================

# %%
# Plot Results
fig = plt.figure(figsize=(8,5))
plt.plot(fpr, tpr, 'b', label = 'Tuned XGBoost: (AUC = %0.2f)' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('Integrity Model: Tuned XGBoost')
plt.savefig('figs/results_figs/cia/tuned_xgb_integrity.png')
plt.show()

# %% [markdown]
# ### Integrity Interpretability (No Action)
# The summary plot combines feature importance with feature effects. Each point on the summary plot is a Shapley value for a feature and an instance. The position on the y-axis is determined by the feature and on the x-axis by the Shapley value. The color represents the value of the feature from low to high. Overlapping points are jittered in y-axis direction, so we get a sense of the distribution of the Shapley values per feature. The features are ordered according to their importance.

# %%
preprocessor = Pipeline(([
    ('encoder', MEstimateEncoder(cols=[col for col in cat_cols if col not in action_cols])),
    ('imputer', IterativeImputer(verbose=2))
]))
sampler = ADASYN()

print('Preprocessing data...')

X_preprocessed = preprocessor.fit_transform(X_noaction, y_confidentiality)

print('Resampling data...')
X_resampled, y_confidentiality_resampled = sampler.fit_resample(X_preprocessed, y_confidentiality)
# Out:
# Preprocessing data...
# [IterativeImputer] Completing matrix with shape (7833, 205)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 15.21
# [IterativeImputer] Change: 7016320.712507278, scaled tolerance: 6800000000.0
# [IterativeImputer] Early stopping criterion reached.
# Resampling data...

# %%
print('Fiting XGBoost...')
xgb_confidentiality = XGBClassifier(**con_optimum)
xgb_confidentiality.fit(X_resampled, y_confidentiality_resampled)

print('SHAP explanations...')
confidentiality_xgb_explainer = shap.TreeExplainer(xgb_confidentiality)
confidentiality_xgb_shap_values = confidentiality_xgb_explainer.shap_values(X_resampled)

plt.title('SHAP Feature Importance: XGBoost Confidentiality Model')
shap.summary_plot(confidentiality_xgb_shap_values, pd.DataFrame(X_resampled, columns=X_noaction.columns))
# Out:
# Fiting XGBoost...
# SHAP explanations...
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.

# %% [markdown]
# ---
# # Predicting Availability

# %% [markdown]
# ### With Action Columns

# %%
confidentiality_results = compare_models(X, y_availability)
# Out:
# [IterativeImputer] Completing matrix with shape (6266, 468)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 120.22
# [IterativeImputer] Change: 172781.40277932974, scaled tolerance: 130000000.0
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (1567, 468)
# [IterativeImputer] Ending imputation round 1/1, elapsed time 0.20
# Fitting XGBoost...
#
# XGBoost Fitted!
# Total Time Elapsed - 0:0:3
# ---------------------------------------------------
# Predicting on validation data...
# Predictions Completed
# Total Time Elapsed - 0:0:3
# ---------------------------------------------------
# ROC-AUC Score: 97.45%
# Accuracy Score: 93.62%
# Precision Score: 91.05%
# Recall Score: 87.61%
# F1 Score: 89.29%
# ---------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.95      0.96      0.95      1091
#         True       0.91      0.88      0.89       476
#
#     accuracy                           0.94      1567
#    macro avg       0.93      0.92      0.92      1567
# weighted avg       0.94      0.94      0.94      1567
#
# ---------------------------------------------------
#
# Confusion Matrix:
#       0    1
# 0  1050   41
# 1    59  417
#
#
# ===================================================
# Fitting Random Forest...
#
# Random Forest Fitted!
# Total Time Elapsed - 0:0:1
# ---------------------------------------------------
# Predicting on validation data...
# Predictions Completed
# Total Time Elapsed - 0:0:1
# ---------------------------------------------------
# ROC-AUC Score: 97.50%
# Accuracy Score: 93.17%
# Precision Score: 90.91%
# Recall Score: 86.13%
# F1 Score: 88.46%
# ---------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.94      0.96      0.95      1091
#         True       0.91      0.86      0.88       476
#
#     accuracy                           0.93      1567
#    macro avg       0.92      0.91      0.92      1567
# weighted avg       0.93      0.93      0.93      1567
#
# ---------------------------------------------------
#
# Confusion Matrix:
#       0    1
# 0  1050   41
# 1    66  410
#
#
# ===================================================
# Fitting SVM...
#
# SVM Fitted!
# Total Time Elapsed - 0:2:56
# ---------------------------------------------------
# Predicting on validation data...
# Predictions Completed
# Total Time Elapsed - 0:3:5
# ---------------------------------------------------
# ROC-AUC Score: 50.75%
# Accuracy Score: 67.45%
# Precision Score: 33.96%
# Recall Score: 7.56%
# F1 Score: 12.37%
# ---------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.70      0.94      0.80      1091
#         True       0.34      0.08      0.12       476
#
#     accuracy                           0.67      1567
#    macro avg       0.52      0.51      0.46      1567
# weighted avg       0.59      0.67      0.59      1567
#
# ---------------------------------------------------
#
# Confusion Matrix:
#       0   1
# 0  1021  70
# 1   440  36
#
#
# ===================================================
# Fitting Naive Bayes...
#
# Naive Bayes Fitted!
# Total Time Elapsed - 0:0:0
# ---------------------------------------------------
# Predicting on validation data...
# Predictions Completed
# Total Time Elapsed - 0:0:0
# ---------------------------------------------------
# ROC-AUC Score: 59.90%
# Accuracy Score: 45.37%
# Precision Score: 35.38%
# Recall Score: 96.64%
# F1 Score: 51.80%
# ---------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.94      0.23      0.37      1091
#         True       0.35      0.97      0.52       476
#
#     accuracy                           0.45      1567
#    macro avg       0.65      0.60      0.44      1567
# weighted avg       0.76      0.45      0.41      1567
#
# ---------------------------------------------------
#
# Confusion Matrix:
#      0    1
# 0  251  840
# 1   16  460
#
#
# ===================================================

# %% [markdown]
# ### Without Action Columns

# %%
confidentiality_noaction_results = compare_models(X_noaction, y_availability, action_cols)
# Out:
# [IterativeImputer] Completing matrix with shape (6266, 200)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 10.72
# [IterativeImputer] Change: 211155.40930613392, scaled tolerance: 130000000.0
# [IterativeImputer] Early stopping criterion reached.
# [IterativeImputer] Completing matrix with shape (1567, 200)
# [IterativeImputer] Ending imputation round 1/1, elapsed time 0.08
# Fitting XGBoost...
#
# XGBoost Fitted!
# Total Time Elapsed - 0:0:1
# ---------------------------------------------------
# Predicting on validation data...
# Predictions Completed
# Total Time Elapsed - 0:0:1
# ---------------------------------------------------
# ROC-AUC Score: 78.49%
# Accuracy Score: 76.13%
# Precision Score: 62.32%
# Recall Score: 54.20%
# F1 Score: 57.98%
# ---------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.81      0.86      0.83      1091
#         True       0.62      0.54      0.58       476
#
#     accuracy                           0.76      1567
#    macro avg       0.72      0.70      0.71      1567
# weighted avg       0.75      0.76      0.76      1567
#
# ---------------------------------------------------
#
# Confusion Matrix:
#      0    1
# 0  935  156
# 1  218  258
#
#
# ===================================================
# Fitting Random Forest...
#
# Random Forest Fitted!
# Total Time Elapsed - 0:0:1
# ---------------------------------------------------
# Predicting on validation data...
# Predictions Completed
# Total Time Elapsed - 0:0:1
# ---------------------------------------------------
# ROC-AUC Score: 78.05%
# Accuracy Score: 74.60%
# Precision Score: 58.82%
# Recall Score: 54.62%
# F1 Score: 56.64%
# ---------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.81      0.83      0.82      1091
#         True       0.59      0.55      0.57       476
#
#     accuracy                           0.75      1567
#    macro avg       0.70      0.69      0.69      1567
# weighted avg       0.74      0.75      0.74      1567
#
# ---------------------------------------------------
#
# Confusion Matrix:
#      0    1
# 0  909  182
# 1  216  260
#
#
# ===================================================
# Fitting SVM...
#
# SVM Fitted!
# Total Time Elapsed - 0:0:58
# ---------------------------------------------------
# Predicting on validation data...
# Predictions Completed
# Total Time Elapsed - 0:1:2
# ---------------------------------------------------
# ROC-AUC Score: 50.21%
# Accuracy Score: 67.52%
# Precision Score: 33.98%
# Recall Score: 7.35%
# F1 Score: 12.09%
# ---------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.70      0.94      0.80      1091
#         True       0.34      0.07      0.12       476
#
#     accuracy                           0.68      1567
#    macro avg       0.52      0.51      0.46      1567
# weighted avg       0.59      0.68      0.59      1567
#
# ---------------------------------------------------
#
# Confusion Matrix:
#       0   1
# 0  1023  68
# 1   441  35
#
#
# ===================================================
# Fitting Naive Bayes...
#
# Naive Bayes Fitted!
# Total Time Elapsed - 0:0:0
# ---------------------------------------------------
# Predicting on validation data...
# Predictions Completed
# Total Time Elapsed - 0:0:0
# ---------------------------------------------------
# ROC-AUC Score: 55.76%
# Accuracy Score: 39.06%
# Precision Score: 32.98%
# Recall Score: 97.48%
# F1 Score: 49.28%
# ---------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.93      0.14      0.24      1091
#         True       0.33      0.97      0.49       476
#
#     accuracy                           0.39      1567
#    macro avg       0.63      0.56      0.36      1567
# weighted avg       0.74      0.39      0.31      1567
#
# ---------------------------------------------------
#
# Confusion Matrix:
#      0    1
# 0  148  943
# 1   12  464
#
#
# ===================================================

# %% [markdown]
# ### Availability Interpretability (No Action)
# The summary plot combines feature importance with feature effects. Each point on the summary plot is a Shapley value for a feature and an instance. The position on the y-axis is determined by the feature and on the x-axis by the Shapley value. The color represents the value of the feature from low to high. Overlapping points are jittered in y-axis direction, so we get a sense of the distribution of the Shapley values per feature. The features are ordered according to their importance.

# %%
preprocessor = Pipeline(([
    ('encoder', MEstimateEncoder(cols=[col for col in cat_cols if col not in action_cols])),
    ('imputer', IterativeImputer(verbose=2))
]))
sampler = ADASYN()

print('Preprocessing data...')

X_preprocessed = preprocessor.fit_transform(X_noaction, y_availability)

print('Resampling data...')
X_resampled, y_availability_resampled = sampler.fit_resample(X_preprocessed, y_availability)

print('Fiting XGBoost...')
xgb_abailability = XGBClassifier(verbose = 3)
xgb_abailability.fit(X_resampled, y_availability_resampled)

print('SHAP explanations...')
availability_explainer = shap.TreeExplainer(xgb_abailability)
availability_shap_values = integrity_explainer.shap_values(X_resampled)
# Out:
# Preprocessing data...
# [IterativeImputer] Completing matrix with shape (7833, 205)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 14.99
# [IterativeImputer] Change: 7019621.1824694555, scaled tolerance: 6800000000.0
# [IterativeImputer] Early stopping criterion reached.
# Resampling data...
# Fiting XGBoost...
# SHAP explanations...
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.

# %%
plt.title('SHAP Feature Importance: Availability Model')
shap.summary_plot(availability_shap_values, pd.DataFrame(X_resampled, columns=X_noactionasset.columns))
